# %%
import json
import networkx as nx 
from networkx.readwrite import json_graph
import pandas as pd
from IPython.display import display, Math, Latex
import re
import sys
import os
sys.path.append("D:\\Users\\figohjs\\Documents\\Network")
from Script.helper_v2 import *
from Script.generateHtml_v4 import generateHtml
from io import StringIO
from elasticsearch import Elasticsearch, helpers

# %% [markdown]
# ### Connect to es

# %%
def multiSearch(fieldName, valueList):
    #record head and body msg for request
    searchBulk = StringIO()
    for value in valueList:
        #head
        headMsg = {'index': indexName}
        searchBulk.write('%s \n' %json.dumps(headMsg))
        #body
        bodyMsg = {"query": {'match':{fieldName:value}}}
        searchBulk.write('%s \n' %json.dumps(bodyMsg))
    
    #start multiSearch
    res = es.msearch(index = indexName, body = searchBulk.getvalue())
    
    #extract hits value
    result = [i['hits']['hits'] for i in res['responses']]
    
    return result

#connect es
es = Elasticsearch([{'host': 'localhost', 'port':9200}], timeout=30)

# %%
#tell info about es cluster
#es.info()

#get all indices in es
sorted(list(es.indices.get_alias('*').keys()))
# Out:
# ['.apm-agent-configuration',
#  '.kibana_1',
#  '.kibana_task_manager_1',
#  '.security-7',
#  'account_db',
#  'assignedreadonly',
#  'audit_trail',
#  'contact_db',
#  'detail_ctr_2013',
#  'detail_ctr_2014',
#  'detail_ctr_2015',
#  'detail_ctr_2016',
#  'detail_ctr_2017',
#  'detail_ctr_2018',
#  'detail_ctr_2019',
#  'detail_ctr_2020',
#  'detail_itis',
#  'detail_str',
#  'distdates',
#  'distratio2020',
#  'distrecords',
#  'entity_db',
#  'itis_db',
#  'leave',
#  'removedrecord',
#  'report_db',
#  'tax']

# %% [markdown]
# ### read data

# %%
#json file - subnetwork
jsonFile = "D:/Users/figohjs/Documents/Network/data/interim/2021-02-19_ScamNetwork52Names.json"
with open(jsonFile, 'r') as f:
    tempGraphDict = json.load(f)

csvFile = "D:/Users/figohjs/Documents/Network/data/raw/subject.csv"
df = pd.read_csv(csvFile)
offenseList = df['Offence'].unique()

#additional namelist for additional scam networks
nameList = []
txtFile = "D:/Users/figohjs/Documents/Network/data/raw/addScamNameList.txt"
with open(txtFile, 'r') as myfile:
    for row in myfile.readlines():
        nameList.append(re.sub('\n','',row))

# %%
len(tempGraphDict['nodes']), len(tempGraphDict['links'])
# Out:
# (48481, 96387)

# %%
#from yan ling - json for other scam-related networks
yanLingJsonFolder = "D:\\Users\\figohjs\\Documents\\Network\\data\\raw\\yanLing"

yanLingRecord = []
for yanLingFile in os.listdir(yanLingJsonFolder):
    with open(yanLingJsonFolder + '\\' + yanLingFile) as input_file:
        for row in input_file.readlines():
            yanLingRecord.append(json.loads(row))    

for record in yanLingRecord:
    tempGraphDict['nodes'] += record['nodes']
    tempGraphDict['links'] += record['links']

# %%
len(tempGraphDict['nodes']), len(tempGraphDict['links'])
# Out:
# (687406, 1167276)

# %% [markdown]
# ### Overview

# %%
#How many person in scam in repo
scamOffense = [i for i in offenseList if re.search("Scam", str(i), re.I)]
dfScam = df[df['Offence'].isin(scamOffense)].copy()
numScamOffense = dfScam.shape[0]
print("Number of scam cases: %s"%numScamOffense)
print("Missing ID: %s"%dfScam[pd.isnull(dfScam['ID'])].shape[0])
print("Number of unique names: %s"%len(dfScam['Name'].unique()))
# Out:
# Number of scam cases: 73
# Missing ID: 73
# Number of unique names: 52

# %%
#clean name
dfScam['CleanName'] = dfScam['Name'].replace(to_replace = ['\(.*\)', '\.'],
                                             value = '',  regex = True).str.strip()
scamNameList  = list(dfScam['CleanName'].unique()) + nameList

#build neoId to name dict
neoIdtoNeoNameDict = {node['NeoId']:node['pName']
                     for node in tempGraphDict['nodes'] if node['label'] in ['Entity']}
neoIdtoNameDictTargetOnly = {i:j for i,j in neoIdtoNeoNameDict.items() if j in scamNameList}

#one name may have more than 1 id
print("Number of unique names found in network: %s"%len(set(neoIdtoNameDictTargetOnly.values())))
# Out:
# Number of unique names found in network: 58

# %%
print("Number of unique nodes: %s"%len(tempGraphDict['nodes']))
print("Number of links: %s"%len(tempGraphDict['links']))
# Out:
# Number of unique nodes: 687406
# Number of links: 1167276

# %%
#build network graph from dict of dict
networkGraph = json_graph.node_link_graph(tempGraphDict)
#find number of subgraphs
subGraphs = nx.connected_components(networkGraph)
#filter out subgraphs with only one node
subGraphsList = [i for i in list(subGraphs) if len(i)!=1]
print("Number of subgraphs: %s"%len(list(subGraphsList)))
# assert len(list(subGraphsList)) == 43, "number of subgraphs should be 43"
# Out:
# Number of subgraphs: 151

# %%
jsonFile = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-25_ScamNetwork48Names.json"
with open(jsonFile, 'w') as file:
    json.dump(tempGraphDict, file)

# %% [markdown]
# ### Mutiple nodes with same name

# %%
[i for i in tempGraphDict['nodes'] if i['NeoId'] == 8209078]
# Out:
# [{'uid': 'e-25e67746-6fcd-421e-974d-e5402e733792',
#   'pOccupation': ['Lawyer / Barrister / Solicitor'],
#   'pName': 'MOHD FAIZAL BIN AHMAD',
#   'pNameList': ['MOHD FAIZAL BIN AHMAD'],
#   'pCountry': ['MALAYSIA'],
#   'pIdList': ['700520016143', 'A1576955'],
#   'contact_list': ['072217828', '0127777828', '073337929', '072217929'],
#   'pOccupationDesc': [],
#   'label': 'Entity',
#   'NeoId': 8209078}]

# %%
[i for i in tempGraphDict['nodes'] if i['NeoId'] == 8288836]
# Out:
# [{'uid': 'e-b37e6a4d-8fa7-4508-b06e-b8815b838d21',
#   'pOccupation': [],
#   'pName': 'MOHD FAIZAL BIN AHMAD',
#   'pNameList': ['MOHD FAIZAL BIN AHMAD'],
#   'pCountry': ['MALAYSIA'],
#   'pIdList': ['840727085669'],
#   'contact_list': ['0122553104', '058072323', '0166613702', '016613702'],
#   'pOccupationDesc': [],
#   'label': 'Entity',
#   'NeoId': 8288836}]

# %%
[i for i in tempGraphDict['nodes'] if i['NeoId'] == 8412685]
# Out:
# [{'uid': 'e-f7923333-87b3-465c-b0c1-fd1805969e1d',
#   'pOccupation': ['Lawyer / Barrister / Solicitor'],
#   'pName': 'MOHD FAIZAL BIN AHMAD',
#   'pNameList': ['MOHD FAIZAL BIN AHMAD', 'MOHD FAIZAL'],
#   'pCountry': ['MALAYSIA'],
#   'pIdList': ['730803145049', 'A2445711'],
#   'contact_list': ['00387360515',
#    '0122902314',
#    '27308541',
#    '0387360515',
#    '0192902314',
#    'MFAIZAL@UDANET.CONM'],
#   'pOccupationDesc': [],
#   'label': 'Entity',
#   'NeoId': 8412685}]

# %%
[i for i in tempGraphDict['nodes'] if i['label'] == 'STR']
# Out:
# [{'uid': 'r-37f1d0c9-a54d-49ab-8b72-60a050f17c23',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'JOHOR',
#   'pTrxAmount': '763798.81',
#   'pReportDate': '20/02/2014',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR financial',
#   'pToTrxDate': '28/01/2014',
#   'pBranchId': 'JOHOR BAHRU (CITY SQUARE)',
#   'pRecordID': 'AA/021/S/2014/000199',
#   'pFromTrxDate': '23/02/2012',
#   'label': 'STR',
#   'NeoId': 14548206},
#  {'uid': 'r-f21ede65-0c1b-475a-85a8-004bdc311606',
#   'pOffence': 'Fraud',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '23/09/2019',
#   'pAttempted': 'Y',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AA/023/S/2019/000406',
#   'label': 'STR',
#   'NeoId': 14564357},
#  {'pOffence': 'Unknown',
#   'pSumInsured': '50000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '30/12/2013',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '1834.93',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-db6abcb5-ef0c-426e-ad66-94bfb492001e',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '16/10/2012',
#   'pRecordID': 'CA/010/S/2013/000056',
#   'pFromTrxDate': '17/10/2011',
#   'label': 'STR',
#   'NeoId': 14734563},
#  {'uid': 'r-9ba129ea-0157-4aff-80fb-0490298e69ce',
#   'pOffence': 'Forgery',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '09/10/2019',
#   'pAttempted': 'Y',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AA/004/S/2019/005288',
#   'label': 'STR',
#   'NeoId': 14425858},
#  {'uid': 'r-b19f5293-2dbd-4d95-8b8d-5c66f2592887',
#   'pOffence': 'Forgery',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '08/10/2019',
#   'pAttempted': 'Y',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AC/004/S/2019/000563',
#   'label': 'STR',
#   'NeoId': 14608112},
#  {'uid': 'r-a22d96b0-27cf-4088-9ea7-110c59615667',
#   'pOffence': 'Smuggling including customs and excise duties and taxes',
#   'pStateId': 'PERAK',
#   'pTrxAmount': '24059905.95',
#   'pReportDate': '23/07/2019',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '21/07/2019',
#   'pBranchId': 'IPOH GARDEN',
#   'pRecordID': 'AA/020/S/2019/002212',
#   'pFromTrxDate': '01/10/2018',
#   'label': 'STR',
#   'NeoId': 14546001},
#  {'uid': 'r-46876e4e-cebd-40c5-9fe4-a74f7fd65737',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '9000.0',
#   'pReportDate': '10/02/2020',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Casino',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '27/01/2020',
#   'pRecordID': 'DA/002/S/2020/000603',
#   'pFromTrxDate': '27/01/2020',
#   'label': 'STR',
#   'NeoId': 17582490},
#  {'uid': 'r-2895e931-bda4-4e19-b9a4-2b2fc80f49a4',
#   'pOffence': 'Unknown',
#   'pSumInsured': '1340000.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '30/11/2017',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '1400000.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/055/S/2017/000010',
#   'pFromTrxDate': '17/11/2017',
#   'label': 'STR',
#   'NeoId': 14742914},
#  {'pOffence': 'Illegal Betting/Gaming/Bookie',
#   'uid': 'r-4550d44c-3ef3-4329-a3f1-172956e534ea',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '12/12/2017',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'Y',
#   'pToTrxDate': '28/11/2017',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AA/010/S/2017/009476',
#   'pFromTrxDate': '03/09/2017',
#   'label': 'STR',
#   'NeoId': 14443080},
#  {'pOffence': 'Money Laundering',
#   'pSumInsured': '46288.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '13/02/2019',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '1603.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-aafe86e5-c79a-47f5-af3c-58543603029c',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '13/02/2019',
#   'pRecordID': 'CA/069/S/2019/000002',
#   'pFromTrxDate': '14/09/2001',
#   'label': 'STR',
#   'NeoId': 14744043},
#  {'uid': 'r-83426904-1626-4c34-80e9-222c17bfcc74',
#   'pOffence': 'Money Laundering',
#   'pSumInsured': '45000.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '30/08/2017',
#   'pRecordTypeID': 'STR Insurance',
#   'pAttempted': 'N',
#   'pPremiumAmount': '3000.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/069/S/2017/000140',
#   'pFromTrxDate': '08/08/2017',
#   'label': 'STR',
#   'NeoId': 14743968},
#  {'pOffence': 'Bribery/Corruption',
#   'pSumInsured': '220000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '18/06/2019',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '200000.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-e31e72e2-4aea-415e-a4c8-d3527c9ad0c9',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '18/06/2019',
#   'pRecordID': 'CA/069/S/2019/000012',
#   'pFromTrxDate': '30/08/2018',
#   'label': 'STR',
#   'NeoId': 14744049},
#  {'uid': 'r-b520b234-1867-4247-b7f1-44fed50df7bb',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '10010.0',
#   'pReportDate': '22/06/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '02/06/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AP/004/S/2015/000119',
#   'pFromTrxDate': '02/06/2015',
#   'label': 'STR',
#   'NeoId': 14720703},
#  {'uid': 'r-40ff43ac-70b9-457e-9909-800d0c64eb4f',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '27505.9',
#   'pReportDate': '19/08/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '22/07/2016',
#   'pRecordID': 'AN/001/S/2016/002706',
#   'pFromTrxDate': '20/06/2016',
#   'label': 'STR',
#   'NeoId': 14706827},
#  {'uid': 'r-830914fe-7240-41ed-8ec5-c42df57fb481',
#   'pOffence': 'Unknown',
#   'pStateId': 'SABAH',
#   'pTrxAmount': '0.0',
#   'pReportDate': '13/10/2014',
#   'pRecordTypeID': 'STR Unit Trust Mgmt Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '31/10/2011',
#   'pRecordID': 'AM/005/S/2014/000061',
#   'pTotalFund': '2000000.0',
#   'pFromTrxDate': '31/10/2011',
#   'label': 'STR',
#   'NeoId': 14684477},
#  {'uid': 'r-ea0b3cfa-6eb6-46c2-b053-03ab5c45df13',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '0.0',
#   'pReportDate': '28/03/2014',
#   'pRecordTypeID': 'STR Unit Trust Mgmt Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '12/02/2014',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AM/005/S/2014/000024',
#   'pTotalFund': '9500000.0',
#   'pFromTrxDate': '04/09/2013',
#   'label': 'STR',
#   'NeoId': 14684441},
#  {'uid': 'r-f05f3ef7-91f0-426e-a838-5ab150b2407b',
#   'pOffence': 'Bribery/Corruption',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '0.0',
#   'pReportDate': '17/05/2019',
#   'pRecordTypeID': 'STR Unit Trust Mgmt Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '19/06/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AJ/069/S/2019/000020',
#   'pTotalFund': '600000.0',
#   'pFromTrxDate': '19/06/2015',
#   'label': 'STR',
#   'NeoId': 14676511},
#  {'uid': 'r-a993b91d-5355-4b41-b612-b95599774d02',
#   'pOffence': 'Bribery/Corruption',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '0.0',
#   'pReportDate': '10/11/2017',
#   'pRecordTypeID': 'STR Unit Trust Mgmt Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '14/09/2017',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AJ/069/S/2017/000009',
#   'pTotalFund': '600000.0',
#   'pFromTrxDate': '27/07/2017',
#   'label': 'STR',
#   'NeoId': 14676478},
#  {'uid': 'r-d5d2b294-407a-4fe9-9984-cbec60669e19',
#   'pOffence': 'Money Laundering',
#   'pSumInsured': '255000.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '23/07/2019',
#   'pRecordTypeID': 'STR Insurance',
#   'pAttempted': 'Y',
#   'pPremiumAmount': '150.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/077/S/2019/000008',
#   'pFromTrxDate': '19/07/2019',
#   'label': 'STR',
#   'NeoId': 14744731},
#  {'pOffence': 'Bribery/Corruption',
#   'pSumInsured': '1400000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '18/06/2019',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '82236.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-de69aebc-3bbb-497d-8967-699dda2b314d',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '18/06/2019',
#   'pRecordID': 'CA/069/S/2019/000010',
#   'pFromTrxDate': '28/11/2017',
#   'label': 'STR',
#   'NeoId': 14744048},
#  {'uid': 'r-5254b6bd-9cbe-43f4-99ea-49e76f6d6c3b',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '1642550.0',
#   'pReportDate': '25/07/2018',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'APPW/0018/2012/S/2018/000015',
#   'pFromTrxDate': '06/07/2018',
#   'label': 'STR',
#   'NeoId': 14733440},
#  {'uid': 'r-d9bcca47-ff36-4f90-a665-f9d9ed69a0ea',
#   'pOffence': 'Fraud',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '210086.0',
#   'pReportDate': '16/01/2017',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '07/11/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2017/000113',
#   'pFromTrxDate': '31/03/2016',
#   'label': 'STR',
#   'NeoId': 14397306},
#  {'uid': 'r-61e8a27c-4f86-4a28-a5c4-68e5b39190da',
#   'pOffence': 'Cheating',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '185286.0',
#   'pReportDate': '05/01/2017',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '01/11/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2016/002322',
#   'pFromTrxDate': '31/03/2016',
#   'label': 'STR',
#   'NeoId': 14397152},
#  {'uid': 'r-7cfb6fa1-43c8-4d35-8625-04ae3578f156',
#   'pOffence': 'Tax Offences',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '174934.0',
#   'pReportDate': '21/10/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '02/10/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2016/002043',
#   'pFromTrxDate': '31/03/2016',
#   'label': 'STR',
#   'NeoId': 14396874},
#  {'pOffence': 'Illegal Currency/Forex Trading',
#   'uid': 'r-f218c89d-b44e-40a8-b28e-2b1c18d04432',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '144184.0',
#   'pReportDate': '11/09/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '26/08/2016',
#   'pRecordID': '117/WP/0821/B/S/2016/001733',
#   'pFromTrxDate': '31/03/2016',
#   'label': 'STR',
#   'NeoId': 14396566},
#  {'uid': 'r-a20dee38-8b1e-4434-a998-a5393ae06ce2',
#   'pOffence': 'Tax Offences',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '113984.0',
#   'pReportDate': '27/08/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '17/08/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2016/001671',
#   'pFromTrxDate': '31/03/2016',
#   'label': 'STR',
#   'NeoId': 14396504},
#  {'uid': 'r-759fd9ed-36c5-4233-b271-b82cc459f016',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '596896.4',
#   'pReportDate': '04/05/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '28/04/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2016/000625',
#   'pFromTrxDate': '07/04/2016',
#   'label': 'STR',
#   'NeoId': 14395460},
#  {'uid': 'r-016cbcf0-ff05-473a-8c8e-0a4e5f5526d5',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '152886.4',
#   'pReportDate': '28/04/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '26/04/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2016/000609',
#   'pFromTrxDate': '07/04/2016',
#   'label': 'STR',
#   'NeoId': 14395444},
#  {'uid': 'r-5d1eb8fc-4244-404f-a6f6-911308617f57',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '132900.0',
#   'pReportDate': '09/04/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '07/04/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0821/B/S/2016/000465',
#   'pFromTrxDate': '07/04/2016',
#   'label': 'STR',
#   'NeoId': 14395301},
#  {'uid': 'r-a5ddb075-7311-44c2-8e97-16e2e40cb06d',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '11034.0',
#   'pReportDate': '16/07/2014',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0062/L/S/2014/000031F',
#   'pFromTrxDate': '17/05/2014',
#   'label': 'STR',
#   'NeoId': 14389074},
#  {'uid': 'r-a22d9912-1338-4288-b834-50aa46c340ef',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '8893.05',
#   'pReportDate': '24/10/2013',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0062/L/S/2013/000089F',
#   'pFromTrxDate': '24/10/2013',
#   'label': 'STR',
#   'NeoId': 14389039},
#  {'uid': 'r-e9f77225-b376-441f-aac0-1785657dadff',
#   'pOffence': 'Bribery/Corruption',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '6260.0',
#   'pReportDate': '21/06/2019',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '12/12/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0014/L/S/2019/000102',
#   'pFromTrxDate': '12/12/2016',
#   'label': 'STR',
#   'NeoId': 14388888},
#  {'uid': 'r-718e87ed-2486-4f7a-b57f-20bf8cf4226d',
#   'pOffence': 'Bribery/Corruption',
#   'pSumInsured': '370000.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '18/06/2020',
#   'pRecordTypeID': 'STR Insurance',
#   'pAttempted': 'N',
#   'pPremiumAmount': '1043.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/077/S/2020/000012',
#   'pFromTrxDate': '07/06/2020',
#   'label': 'STR',
#   'NeoId': 18310981},
#  {'uid': 'r-b555d990-2ed5-46f2-a2ac-e50ee52fdc88',
#   'pOffence': 'Unknown',
#   'pSumInsured': '90000.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '14/12/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '6000.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/078/S/2013/000069',
#   'pFromTrxDate': '17/09/2013',
#   'label': 'STR',
#   'NeoId': 14744809},
#  {'uid': 'r-7e36cd8f-c8f1-4ffd-8eb6-cfce31614320',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '36007.0',
#   'pReportDate': '04/11/2015',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '30/10/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0675/B/S/2015/000146',
#   'pFromTrxDate': '29/10/2015',
#   'label': 'STR',
#   'NeoId': 14393718},
#  {'uid': 'r-7d5d6fd2-e4f8-43be-ac31-7cb7f51b30f7',
#   'pOffence': 'Money Laundering',
#   'pSumInsured': '447798.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '08/04/2016',
#   'pRecordTypeID': 'STR Insurance',
#   'pAttempted': 'N',
#   'pPremiumAmount': '400000.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/069/S/2016/000002',
#   'pFromTrxDate': '07/02/2011',
#   'label': 'STR',
#   'NeoId': 14743777},
#  {'uid': 'r-487fa90b-d727-4258-9c79-213d28eab4ce',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'TERENGGANU',
#   'pTrxAmount': '58475.0',
#   'pReportDate': '08/08/2019',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '22/07/2019',
#   'pRecordID': 'AN/001/S/2019/001498',
#   'pFromTrxDate': '18/06/2019',
#   'label': 'STR',
#   'NeoId': 14715247},
#  {'uid': 'r-b00325ee-a602-4433-85bf-44b387867c25',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '58307.55',
#   'pReportDate': '27/09/2019',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '21/09/2019',
#   'pRecordID': 'AN/001/S/2019/001835',
#   'pFromTrxDate': '02/08/2019',
#   'label': 'STR',
#   'NeoId': 14715583},
#  {'uid': 'r-892fd31b-8957-4a5a-8667-da9e6b6c1b2b',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '57751.0',
#   'pReportDate': '17/12/2019',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '04/12/2019',
#   'pRecordID': 'AN/001/S/2019/002266',
#   'pFromTrxDate': '04/10/2019',
#   'label': 'STR',
#   'NeoId': 14795325},
#  {'uid': 'r-f79aca20-c7c9-4ee5-98f9-20faa4575e1a',
#   'pOffence': 'Fraud',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '05/11/2019',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '05/11/2019',
#   'pRecordID': 'AC/010/S/2019/000642',
#   'pFromTrxDate': '05/11/2019',
#   'label': 'STR',
#   'NeoId': 14627831},
#  {'uid': 'r-53911ecf-91aa-4038-9798-403e4e543e71',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '12178.8',
#   'pReportDate': '18/09/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '01/07/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/006215',
#   'pFromTrxDate': '05/06/2015',
#   'label': 'STR',
#   'NeoId': 14701737},
#  {'uid': 'r-0d082bea-a3d3-4be8-a599-e31fa24fc02c',
#   'pOffence': 'Unknown',
#   'pStateId': 'TERENGGANU',
#   'pTrxAmount': '31986.49',
#   'pReportDate': '05/05/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '16/03/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2016/001123',
#   'pFromTrxDate': '01/02/2016',
#   'label': 'STR',
#   'NeoId': 14705249},
#  {'uid': 'r-b15b7e4a-0d12-4de0-9225-828c3f0a7904',
#   'pOffence': 'Unlicensed Banking Business including offshore',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '169891.2',
#   'pReportDate': '03/03/2017',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Money changer',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '16/01/2017',
#   'pRecordID': '117/WP/0821/B/S/2017/000722',
#   'pFromTrxDate': '16/01/2017',
#   'label': 'STR',
#   'NeoId': 14397915},
#  {'uid': 'r-84daab22-2278-4012-9270-2248955dbe2e',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '45980.0',
#   'pReportDate': '14/01/2016',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '24/12/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/WP/0481/B/S/2016/000106',
#   'pFromTrxDate': '21/11/2015',
#   'label': 'STR',
#   'NeoId': 14391108},
#  {'uid': 'r-d29b7284-f920-410c-8c7d-90a2cf4e4a80',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '24618.0',
#   'pReportDate': '06/12/2018',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '30/11/2018',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '617616K/S/2018/000193',
#   'pFromTrxDate': '07/12/2016',
#   'label': 'STR',
#   'NeoId': 14399620},
#  {'uid': 'r-5957ce3b-3bdf-4738-ac9f-043fc032f3af',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '136000.0',
#   'pReportDate': '15/01/2014',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '17/10/2013',
#   'pRecordID': 'DA/002/S/2014/000018',
#   'pFromTrxDate': '17/10/2013',
#   'label': 'STR',
#   'NeoId': 14746779},
#  {'uid': 'r-c62ce1ef-4bda-4486-ab4a-11c9e48609da',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '178618.6',
#   'pReportDate': '29/07/2019',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '07/03/2019',
#   'pBranchId': 'TAMAN SERI GOMBAK',
#   'pRecordID': 'AA/010/S/2019/014993',
#   'pFromTrxDate': '07/03/2019',
#   'label': 'STR',
#   'NeoId': 14475601},
#  {'uid': 'r-6266b8d7-b4d6-49a7-8dce-d0af51aa7dd7',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '3142000.0',
#   'pReportDate': '08/09/2017',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '31/07/2017',
#   'pRecordID': 'DA/002/S/2017/004936',
#   'pFromTrxDate': '20/07/2017',
#   'label': 'STR',
#   'NeoId': 14769947},
#  {'uid': 'r-b9600eb1-d8cd-4c27-9248-a7839beb2771',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '58872888.5',
#   'pReportDate': '11/09/2017',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '27/08/2017',
#   'pRecordID': 'DA/002/S/2017/005029',
#   'pFromTrxDate': '20/07/2017',
#   'label': 'STR',
#   'NeoId': 14770037},
#  {'uid': 'r-834cd798-9d32-48ba-bfb1-b3bf64a245c3',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '62570530.0',
#   'pReportDate': '05/10/2017',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '10/09/2017',
#   'pRecordID': 'DA/002/S/2017/005306',
#   'pFromTrxDate': '02/09/2017',
#   'label': 'STR',
#   'NeoId': 14770305},
#  {'uid': 'r-e7f28dd1-65d3-4d29-824b-f1d9a716b087',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '7603000.0',
#   'pReportDate': '05/10/2017',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '08/08/2017',
#   'pRecordID': 'DA/002/S/2017/005508',
#   'pFromTrxDate': '08/08/2017',
#   'label': 'STR',
#   'NeoId': 14770501},
#  {'uid': 'r-cc9efc61-6294-4bc8-a7d7-16aabadeac76',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '22708000.0',
#   'pReportDate': '05/11/2017',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '05/09/2017',
#   'pRecordID': 'DA/002/S/2017/006034',
#   'pFromTrxDate': '02/09/2017',
#   'label': 'STR',
#   'NeoId': 14771016},
#  {'uid': 'r-82429c32-82da-4166-8c9f-eda80c1858fb',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '2499220.0',
#   'pReportDate': '02/02/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '16/12/2017',
#   'pRecordID': 'DA/002/S/2018/000349',
#   'pFromTrxDate': '16/12/2017',
#   'label': 'STR',
#   'NeoId': 14772984},
#  {'uid': 'r-71fad7ac-55e1-4765-b321-8a8cb111a1fe',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '10556225.0',
#   'pReportDate': '29/01/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '19/12/2017',
#   'pRecordID': 'DA/002/S/2018/000402',
#   'pFromTrxDate': '17/12/2017',
#   'label': 'STR',
#   'NeoId': 14773036},
#  {'uid': 'r-ea7e4a85-cbb9-4bb8-bbf8-6100796f8681',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '7987.22',
#   'pReportDate': '12/09/2017',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/KD/0143/L-1/S/2017/000105',
#   'pFromTrxDate': '16/08/2017',
#   'label': 'STR',
#   'NeoId': 14384251},
#  {'uid': 'r-083dbd64-c150-4e43-ba73-7f523e553ae9',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '15000.0',
#   'pReportDate': '04/10/2017',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/KD/0143/L-1/S/2017/000126',
#   'pFromTrxDate': '02/10/2017',
#   'label': 'STR',
#   'NeoId': 14384272},
#  {'uid': 'r-02d1d326-09fb-43d9-b251-95eef9a835e2',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '12499.99',
#   'pReportDate': '18/09/2014',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/KD/0782/B-1/S/2015/000066F',
#   'pFromTrxDate': '15/09/2014',
#   'label': 'STR',
#   'NeoId': 14384452},
#  {'pOffence': 'Illegal Currency/Forex Trading',
#   'uid': 'r-0cd16d20-2f1a-49d0-ad91-cb652c2e7683',
#   'pTrxAmount': '1568865.23',
#   'pStateId': 'KEDAH',
#   'pReportDate': '03/05/2017',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '25/04/2017',
#   'pBranchId': 'SUNGAI PETANI',
#   'pRecordID': 'AA/020/S/2017/000746',
#   'pFromTrxDate': '20/02/2017',
#   'label': 'STR',
#   'NeoId': 14538107},
#  {'uid': 'r-3ead63c1-733d-4480-8700-83805010e2d7',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'PULAU PINANG',
#   'pTrxAmount': '0.0',
#   'pReportDate': '20/03/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'Y',
#   'pBranchId': 'BUKIT MERTAJAM',
#   'pRecordID': 'AA/018/S/2018/000194',
#   'label': 'STR',
#   'NeoId': 14529429},
#  {'uid': 'r-b6306356-e17d-4073-8bb1-fbc560179ed1',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'PULAU PINANG',
#   'pTrxAmount': '350000.0',
#   'pReportDate': '25/05/2017',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'STANDARD CHARTERED BANK BUKIT TENGAH',
#   'pToTrxDate': '12/05/2017',
#   'pRecordID': 'AA/023/S/2017/000470',
#   'pFromTrxDate': '21/02/2017',
#   'label': 'STR',
#   'NeoId': 14562619},
#  {'uid': 'r-8dbd74be-c8dc-43cb-a71c-7c2ed91c03aa',
#   'pOffence': 'Investment Scam',
#   'pStateId': 'KEDAH',
#   'pTrxAmount': '5533865.0',
#   'pReportDate': '15/05/2017',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'JLN. KG. BARU - SG. PETANI',
#   'pRecordID': 'AA/010/S/2017/000900',
#   'pFromTrxDate': '22/02/2017',
#   'label': 'STR',
#   'NeoId': 14434557},
#  {'uid': 'r-89e7231c-5bca-43d8-865d-85909ff35f15',
#   'pOffence': 'Money Laundering',
#   'pTrxAmount': '0.0',
#   'pStateId': 'KEDAH',
#   'pReportDate': '08/06/2017',
#   'pAttempted': 'Y',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'JLN. KG. BARU - SG. PETANI',
#   'pRecordID': 'AA/010/S/2017/001238',
#   'label': 'STR',
#   'NeoId': 14434892},
#  {'uid': 'r-680f8060-4810-4fd3-b4bf-c637e38a487c',
#   'pOffence': 'Fraud',
#   'pStateId': 'PULAU PINANG',
#   'pTrxAmount': '1450000.0',
#   'pReportDate': '28/07/2017',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'CPI - BUTTERWORTH',
#   'pToTrxDate': '17/05/2017',
#   'pRecordID': 'AC/013/S/2017/002107',
#   'pFromTrxDate': '01/01/2017',
#   'label': 'STR',
#   'NeoId': 14637101},
#  {'uid': 'r-7b88a4f2-10a1-4143-ada3-c43f629add90',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '159040.0',
#   'pReportDate': '02/07/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '13/05/2018',
#   'pRecordID': 'DA/002/S/2018/003109',
#   'pFromTrxDate': '13/05/2018',
#   'label': 'STR',
#   'NeoId': 14775664},
#  {'pOffence': 'Unlicensed remittance services',
#   'uid': 'r-1227a4c1-1310-448a-a77f-d963d9b68afa',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '62911.53',
#   'pReportDate': '02/07/2020',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '22/06/2020',
#   'pRecordID': 'AP/1220176V/S/2020/000012',
#   'pFromTrxDate': '01/04/2020',
#   'label': 'STR',
#   'NeoId': 18310880},
#  {'uid': 'r-ff3dead4-23eb-4972-bc9e-7524b259bb9b',
#   'pOffence': 'Fraud',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '557673.49',
#   'pReportDate': '25/03/2019',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '04/03/2019',
#   'pBranchId': 'MEGAMALL MID VALLEY',
#   'pRecordID': 'AA/010/S/2019/006813',
#   'pFromTrxDate': '01/01/2018',
#   'label': 'STR',
#   'NeoId': 14467978},
#  {'uid': 'r-eae50b7f-2646-4e8d-9652-f1cbd0785501',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '23106.42',
#   'pReportDate': '22/07/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '18/05/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/004084',
#   'pFromTrxDate': '23/03/2015',
#   'label': 'STR',
#   'NeoId': 14699641},
#  {'uid': 'r-bb9fe052-34b6-414d-8149-27c0a063edd2',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '23142.12',
#   'pReportDate': '17/05/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '20/06/2015',
#   'pRecordID': 'AN/001/S/2015/005254',
#   'pFromTrxDate': '08/05/2015',
#   'label': 'STR',
#   'NeoId': 14700805},
#  {'uid': 'r-3c7d88ca-1769-4e8d-adf7-29fda066f2f1',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '24041.04',
#   'pReportDate': '18/09/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '23/07/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/006157',
#   'pFromTrxDate': '25/06/2015',
#   'label': 'STR',
#   'NeoId': 14701680},
#  {'uid': 'r-3f78563d-840c-49b7-845e-ec0d740e6550',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '29599.57',
#   'pReportDate': '31/10/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '07/09/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/007004',
#   'pFromTrxDate': '06/08/2015',
#   'label': 'STR',
#   'NeoId': 14702503},
#  {'uid': 'r-110414e1-0a66-49f3-b69d-392bfa974fda',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '40265.69',
#   'pReportDate': '07/10/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '07/09/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/007084',
#   'pFromTrxDate': '28/07/2015',
#   'label': 'STR',
#   'NeoId': 14702578},
#  {'uid': 'r-8ca1f051-b388-4cba-9bd3-15b0b8b13f87',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '2500.0',
#   'pReportDate': '14/09/2015',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '14/08/2015',
#   'pRecordID': 'AP/012/S/2015/000116',
#   'pFromTrxDate': '14/08/2015',
#   'label': 'STR',
#   'NeoId': 14725718},
#  {'uid': 'r-6a323bbe-2ac4-4b0e-95f1-770da2e90359',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '4168339.18',
#   'pReportDate': '29/06/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'IOI MALL, PUCHONG',
#   'pToTrxDate': '16/05/2018',
#   'pRecordID': 'AA/021/S/2018/000596',
#   'pFromTrxDate': '02/01/2017',
#   'label': 'STR',
#   'NeoId': 14552404},
#  {'uid': 'r-37161fe0-c080-4ea7-979f-5012de828e63',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '3834226.46',
#   'pReportDate': '27/06/2019',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'IOI MALL, PUCHONG',
#   'pToTrxDate': '15/06/2019',
#   'pRecordID': 'AA/021/S/2019/000973',
#   'pFromTrxDate': '02/01/2018',
#   'label': 'STR',
#   'NeoId': 14554020},
#  {'uid': 'r-0a8f224b-2778-45cb-ad18-426e8a49b2e0',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '06/03/2020',
#   'pAttempted': 'Y',
#   'pRecordTypeID': 'STR financial',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AA/004/S/2020/001374',
#   'label': 'STR',
#   'NeoId': 17937699},
#  {'uid': 'r-845dbcd5-9848-4eeb-8753-e14b5da9b71b',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '05/06/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/001549',
#   'label': 'STR',
#   'NeoId': 14686854},
#  {'uid': 'r-e57dcfe7-b4d3-4d81-98ea-bdb1bc97fc02',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '34810.69',
#   'pReportDate': '01/04/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '24/01/2014',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2014/001502',
#   'pFromTrxDate': '03/01/2014',
#   'label': 'STR',
#   'NeoId': 14691991},
#  {'uid': 'r-2cfa5b1c-18b2-4f45-bf77-06ed1fbb3ad9',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '400284.82',
#   'pReportDate': '03/07/2015',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '19/06/2015',
#   'pBranchId': 'JALAN  KENARI',
#   'pRecordID': 'AA/010/S/2015/000879',
#   'pFromTrxDate': '01/07/2014',
#   'label': 'STR',
#   'NeoId': 14430491},
#  {'uid': 'r-dac43dc1-42b4-4c8a-b13c-7cd9dc7e0675',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '4246.41',
#   'pReportDate': '22/05/2015',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'BDC Swiss Inn',
#   'pToTrxDate': '30/04/2015',
#   'pRecordID': 'AC/001/S/2015/000163',
#   'pFromTrxDate': '08/04/2015',
#   'label': 'STR',
#   'NeoId': 14570776},
#  {'uid': 'r-b4aa3cec-7839-4229-b84f-094d445ba6b2',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '12/06/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/001872',
#   'label': 'STR',
#   'NeoId': 14687159},
#  {'uid': 'r-c386eee8-7184-4afe-8eb4-6c8393d749b5',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '09/08/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/002489',
#   'label': 'STR',
#   'NeoId': 14687756},
#  {'uid': 'r-c448993e-a614-4f4a-a58c-375b2914e129',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '119351.4',
#   'pReportDate': '09/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '16/09/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004243',
#   'pFromTrxDate': '18/08/2013',
#   'label': 'STR',
#   'NeoId': 14689438},
#  {'uid': 'r-90c56292-d325-48bd-bd59-d929b31a3c98',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '17/01/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2012/008820',
#   'label': 'STR',
#   'NeoId': 14685142},
#  {'uid': 'r-e8b83c26-f46b-4605-a621-4a0e28c49b7e',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '22/03/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/000582',
#   'label': 'STR',
#   'NeoId': 14685935},
#  {'uid': 'r-07a19280-c1d9-4865-9941-0581648c7a9c',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '13/07/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/002307',
#   'label': 'STR',
#   'NeoId': 14687577},
#  {'uid': 'r-a6707df5-8310-41e8-94e1-5901698313a2',
#   'pOffence': 'Unknown',
#   'pStateId': 'SARAWAK',
#   'pTrxAmount': '72976.0',
#   'pReportDate': '03/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '17/11/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2014/000090',
#   'pFromTrxDate': '01/10/2013',
#   'label': 'STR',
#   'NeoId': 14690590},
#  {'uid': 'r-c5cdb2cb-84d0-402b-8bb5-92ccc6eb59c2',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '07/02/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/000136',
#   'label': 'STR',
#   'NeoId': 14685504},
#  {'uid': 'r-f18a729d-bf80-43ce-83eb-b0920fb4803c',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '73665.62',
#   'pReportDate': '16/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '12/11/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/005279',
#   'pFromTrxDate': '03/10/2013',
#   'label': 'STR',
#   'NeoId': 14690470},
#  {'uid': 'r-8210c65f-8bce-409b-a12e-d22db81c8d65',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '37570.77',
#   'pReportDate': '29/03/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '31/12/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2014/001000',
#   'pFromTrxDate': '02/12/2013',
#   'label': 'STR',
#   'NeoId': 14691490},
#  {'uid': 'r-6c899152-1b6b-48a8-9052-e9e25dcf301a',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '29690.89',
#   'pReportDate': '25/07/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '30/05/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/004327',
#   'pFromTrxDate': '01/04/2015',
#   'label': 'STR',
#   'NeoId': 14699883},
#  {'uid': 'r-bbfb057d-8492-4c0b-b807-da3fc69da82a',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '14251.24',
#   'pReportDate': '09/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '04/10/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004743',
#   'pFromTrxDate': '18/09/2013',
#   'label': 'STR',
#   'NeoId': 14689937},
#  {'uid': 'r-fec558a0-4564-45f7-982b-138468bd4133',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '60138.55',
#   'pReportDate': '10/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '17/10/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004810',
#   'pFromTrxDate': '26/08/2013',
#   'label': 'STR',
#   'NeoId': 14690003},
#  {'uid': 'r-e941aa9f-a51a-4e4d-b0e2-062da4953cc8',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '19803.01',
#   'pReportDate': '20/06/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '24/02/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/002083',
#   'pFromTrxDate': '31/01/2015',
#   'label': 'STR',
#   'NeoId': 14697649},
#  {'uid': 'r-ffd44953-b3f3-4390-bb70-a5ac4412a991',
#   'pOffence': 'Fraud',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '593644.62',
#   'pReportDate': '07/06/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'TMN CONNAUGHT',
#   'pToTrxDate': '15/03/2018',
#   'pRecordID': 'AA/003/S/2018/000222',
#   'pFromTrxDate': '04/01/2018',
#   'label': 'STR',
#   'NeoId': 14410358},
#  {'uid': 'r-b6cb2185-17b4-4cd6-b9a4-da56dea9d1b9',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '66199.0',
#   'pReportDate': '10/04/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '21/02/2018',
#   'pBranchId': 'AMBANK (M) BERHAD',
#   'pRecordID': 'AA/004/S/2018/001220',
#   'pFromTrxDate': '25/01/2018',
#   'label': 'STR',
#   'NeoId': 14416888},
#  {'uid': 'r-44fab447-2a44-4ae9-9518-1c802ee2c245',
#   'pOffence': 'Fraud',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '170165.0',
#   'pReportDate': '21/02/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '29/01/2018',
#   'pBranchId': 'AMBANK (M) BERHAD',
#   'pRecordID': 'AA/004/S/2018/000565',
#   'pFromTrxDate': '07/02/2017',
#   'label': 'STR',
#   'NeoId': 14416234},
#  {'uid': 'r-469edfc3-4f08-47d5-9cc3-64efd890f78b',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '19645.6',
#   'pReportDate': '15/01/2015',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '23/10/2014',
#   'pBranchId': 'TAMAN CONNAUGHT',
#   'pRecordID': 'AA/010/S/2015/000113',
#   'pFromTrxDate': '05/02/2014',
#   'label': 'STR',
#   'NeoId': 14429725},
#  {'uid': 'r-b2a55a27-b71d-4b05-8a20-923101126348',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '49900.5',
#   'pReportDate': '18/04/2014',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'BALAKONG',
#   'pToTrxDate': '17/03/2014',
#   'pRecordID': 'AC/018/S/2014/000014',
#   'pFromTrxDate': '17/03/2014',
#   'label': 'STR',
#   'NeoId': 14662473},
#  {'uid': 'r-be5350c9-3db1-47d4-b738-d4ce6636c959',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '450078.9',
#   'pReportDate': '12/09/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '30/06/2018',
#   'pBranchId': 'SHAH ALAM - SEC 15B',
#   'pRecordID': 'AA/004/S/2018/003221',
#   'pFromTrxDate': '28/05/2018',
#   'label': 'STR',
#   'NeoId': 14418888},
#  {'pOffence': 'Internet Scams/Wire Transfer Fraud',
#   'uid': 'r-7ba3788d-5b6e-4b5b-bb9f-5987a1bad136',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '2629637.87',
#   'pReportDate': '05/06/2018',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'SEKSYEN 18, SHAH ALAM',
#   'pRecordID': 'AA/010/S/2018/007047',
#   'pFromTrxDate': '23/05/2018',
#   'label': 'STR',
#   'NeoId': 14450533},
#  {'pOffence': 'Internet Scams/Wire Transfer Fraud',
#   'uid': 'r-972fea26-c446-42ee-8644-b41be31c875b',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '449903.37',
#   'pReportDate': '02/09/2014',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pBranchId': 'KL CITY MAIN OFFICE',
#   'pToTrxDate': '17/06/2014',
#   'pRecordID': 'AA/020/S/2014/001562',
#   'pFromTrxDate': '01/04/2014',
#   'label': 'STR',
#   'NeoId': 14533625},
#  {'uid': 'r-be45ad8a-ffd7-4775-8355-714405c47837',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '543671.7',
#   'pReportDate': '19/03/2013',
#   'pRecordTypeID': 'STR financial',
#   'pAttempted': 'N',
#   'pToTrxDate': '31/07/2012',
#   'pBranchId': 'TAMAN SETIAWANGSA',
#   'pRecordID': 'AA/010/S/2013/000022',
#   'pFromTrxDate': '31/05/2012',
#   'label': 'STR',
#   'NeoId': 14427537},
#  {'uid': 'r-d2294a21-9314-4d26-84e8-f55ebc8eb48f',
#   'pOffence': 'Unknown',
#   'pStateId': 'SARAWAK',
#   'pTrxAmount': '42668.7',
#   'pReportDate': '09/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '01/09/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004210',
#   'pFromTrxDate': '25/07/2013',
#   'label': 'STR',
#   'NeoId': 14689405},
#  {'uid': 'r-16be11ad-77a6-49d3-a7f5-df81b25030d0',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '160379.94',
#   'pReportDate': '28/12/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '22/10/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/007898',
#   'pFromTrxDate': '07/10/2015',
#   'label': 'STR',
#   'NeoId': 14703371},
#  {'uid': 'r-0aa78350-9be5-4521-9b9d-42183ae504a4',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '60717.25',
#   'pReportDate': '11/04/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '11/01/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2016/000378',
#   'pFromTrxDate': '12/12/2015',
#   'label': 'STR',
#   'NeoId': 14704508},
#  {'uid': 'r-9cb7378a-464d-4f9e-a1af-34c3433bc968',
#   'pOffence': 'Unknown',
#   'pStateId': 'SARAWAK',
#   'pTrxAmount': '63659.98',
#   'pReportDate': '09/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '30/09/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004490',
#   'pFromTrxDate': '05/08/2013',
#   'label': 'STR',
#   'NeoId': 14689685},
#  {'uid': 'r-91217c35-5dd8-4881-a202-c2440747eea4',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '12/06/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/001888',
#   'label': 'STR',
#   'NeoId': 14687175},
#  {'uid': 'r-be86ef42-1552-4ff7-bf66-f2e90d2d2603',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '58333.37',
#   'pReportDate': '04/08/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '03/06/2014',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2014/003177',
#   'pFromTrxDate': '09/04/2014',
#   'label': 'STR',
#   'NeoId': 14693663},
#  {'uid': 'r-5609d7f0-4828-4fa9-bfdf-408535500a23',
#   'pOffence': 'Unknown',
#   'pStateId': 'SARAWAK',
#   'pTrxAmount': '81079.06',
#   'pReportDate': '06/09/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '03/08/2014',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2014/003814',
#   'pFromTrxDate': '26/06/2014',
#   'label': 'STR',
#   'NeoId': 14694300},
#  {'uid': 'r-54e01857-62e1-48ff-8f90-ac1ebb9ed7f7',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '65556.18',
#   'pReportDate': '11/08/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '14/05/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/004507',
#   'pFromTrxDate': '24/04/2015',
#   'label': 'STR',
#   'NeoId': 14700063},
#  {'uid': 'r-d65e7985-ca34-4329-b8a2-3431614a2bfe',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '23/01/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2012/008879',
#   'label': 'STR',
#   'NeoId': 14685201},
#  {'uid': 'r-6e1ed7b6-01cc-42a3-8a84-8b30907ebb84',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '12/02/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/000265',
#   'label': 'STR',
#   'NeoId': 14685629},
#  {'uid': 'r-c0dc254a-613c-4cf5-922d-16fd8149b25d',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '104092.63',
#   'pReportDate': '06/12/2013',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '15/08/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/003545',
#   'pFromTrxDate': '15/07/2013',
#   'label': 'STR',
#   'NeoId': 14688750},
#  {'uid': 'r-9df1838a-b27b-40d9-8d29-00431ac5a838',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '17457.51',
#   'pReportDate': '06/12/2013',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '15/08/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/003606',
#   'pFromTrxDate': '20/06/2013',
#   'label': 'STR',
#   'NeoId': 14688808},
#  {'uid': 'r-e4df2165-c2a1-4b48-abfc-2aacecdcf70d',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '49907.18',
#   'pReportDate': '03/12/2013',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '26/09/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004461',
#   'pFromTrxDate': '07/08/2013',
#   'label': 'STR',
#   'NeoId': 14689656},
#  {'uid': 'r-8cbff54c-1b36-468f-bc4f-b461fc61719d',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '72828.74',
#   'pReportDate': '13/04/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '18/01/2016',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2016/000357',
#   'pFromTrxDate': '25/11/2015',
#   'label': 'STR',
#   'NeoId': 14704487},
#  {'uid': 'r-2d17e93d-d5d4-4d9a-8dba-3cadcb031dd3',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '40553.51',
#   'pReportDate': '21/07/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '27/05/2016',
#   'pRecordID': 'AN/001/S/2016/002162',
#   'pFromTrxDate': '16/04/2016',
#   'label': 'STR',
#   'NeoId': 14706283},
#  {'uid': 'r-6cf63450-84be-4b35-8d84-f9f56ecea6e9',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '55022.1',
#   'pReportDate': '29/09/2016',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '20/09/2016',
#   'pRecordID': 'AN/001/S/2016/003548',
#   'pFromTrxDate': '22/07/2016',
#   'label': 'STR',
#   'NeoId': 14707669},
#  {'uid': 'r-2119e7c6-16af-4324-8a4b-721f246d8617',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '37294.48',
#   'pReportDate': '01/02/2017',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '10/11/2016',
#   'pRecordID': 'AN/001/S/2016/004348',
#   'pFromTrxDate': '27/10/2016',
#   'label': 'STR',
#   'NeoId': 14708468},
#  {'uid': 'r-e6eefc8f-631f-4f0a-a271-ffccc83075b4',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '19068.35',
#   'pReportDate': '21/03/2017',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '08/02/2017',
#   'pRecordID': 'AN/001/S/2017/000739',
#   'pFromTrxDate': '12/01/2017',
#   'label': 'STR',
#   'NeoId': 14709471},
#  {'uid': 'r-3d69566a-c4c2-477a-a310-0155e51b06c0',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '22452.75',
#   'pReportDate': '21/07/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '09/04/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/003353',
#   'pFromTrxDate': '20/02/2015',
#   'label': 'STR',
#   'NeoId': 14698913},
#  {'uid': 'r-fbbfd742-ce14-4b59-9051-6f987856667d',
#   'pOffence': 'Unknown',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '483.01',
#   'pReportDate': '01/11/2014',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '26/08/2014',
#   'pRecordID': 'AP/012/S/2014/000315',
#   'pFromTrxDate': '26/08/2014',
#   'label': 'STR',
#   'NeoId': 14725569},
#  {'uid': 'r-4bf4d518-96ce-4979-9774-3918947840a8',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '21/02/2013',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/000471',
# ...
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '20/01/2019',
#   'pRecordID': 'DA/002/S/2019/000595',
#   'pFromTrxDate': '18/01/2019',
#   'label': 'STR',
#   'NeoId': 14778982},
#  {'uid': 'r-3d17bfe6-4bc1-4781-97c3-ba53d5c40711',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '1316250.0',
#   'pReportDate': '24/01/2019',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '05/01/2019',
#   'pRecordID': 'DA/002/S/2019/000268',
#   'pFromTrxDate': '04/01/2019',
#   'label': 'STR',
#   'NeoId': 14778667},
#  {'uid': 'r-0d8d9ff8-df30-4659-af92-212661baa93d',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '2174550.0',
#   'pReportDate': '08/10/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '10/09/2018',
#   'pRecordID': 'DA/002/S/2018/004569',
#   'pFromTrxDate': '10/09/2018',
#   'label': 'STR',
#   'NeoId': 14777097},
#  {'uid': 'r-0c4b3a61-2425-442e-b4ea-329f544648c6',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '3943000.0',
#   'pReportDate': '31/07/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '28/06/2018',
#   'pRecordID': 'DA/002/S/2018/003607',
#   'pFromTrxDate': '28/06/2018',
#   'label': 'STR',
#   'NeoId': 14776149},
#  {'uid': 'r-4bcea85e-6b27-4c62-a95d-2ddd437aed3f',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '600000.0',
#   'pReportDate': '14/06/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '10/05/2018',
#   'pRecordID': 'DA/002/S/2018/002918',
#   'pFromTrxDate': '10/05/2018',
#   'label': 'STR',
#   'NeoId': 14775478},
#  {'uid': 'r-b48a7be4-6cac-4d57-b47f-36725e234210',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '274118.0',
#   'pReportDate': '09/09/2016',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '07/08/2016',
#   'pRecordID': 'DA/002/S/2016/007032',
#   'pFromTrxDate': '07/08/2016',
#   'label': 'STR',
#   'NeoId': 14762909},
#  {'uid': 'r-8e6591d2-4156-4de5-a02f-39696755ac8e',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '484000.0',
#   'pReportDate': '02/07/2016',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '28/05/2016',
#   'pRecordID': 'DA/002/S/2016/004399',
#   'pFromTrxDate': '28/05/2016',
#   'label': 'STR',
#   'NeoId': 14760386},
#  {'uid': 'r-706242fe-e278-4914-aa3d-dc1c4e3727da',
#   'pOffence': 'Bribery/Corruption',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '12/07/2017',
#   'pRecordTypeID': 'STR Securities',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '12/07/2017',
#   'pRecordID': 'AH/015/S/2017/000013',
#   'pTotalFund': '0.0',
#   'pFromTrxDate': '29/05/2009',
#   'label': 'STR',
#   'NeoId': 14674316},
#  {'uid': 'r-ec240db9-e8b4-4985-a9a7-28036d82a537',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '300000.0',
#   'pReportDate': '25/11/2014',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '31/07/2014',
#   'pRecordID': 'DA/002/S/2014/001511',
#   'pFromTrxDate': '31/07/2014',
#   'label': 'STR',
#   'NeoId': 14748272},
#  {'uid': 'r-9d821ec0-4aa4-45d3-9911-620b16d2cbcd',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'NEGERI SEMBILAN',
#   'pTrxAmount': '51086.0',
#   'pReportDate': '28/09/2020',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '04/09/2020',
#   'pRecordID': 'AN/001/S/2020/001705',
#   'pFromTrxDate': '05/06/2020',
#   'label': 'STR',
#   'NeoId': 18858630},
#  {'uid': 'r-4c84e273-db7a-4efb-869e-2d08f6216844',
#   'pOffence': 'Unknown',
#   'pStateId': 'W.P KUALA LUMPUR',
#   'pTrxAmount': '12364.0',
#   'pReportDate': '31/10/2020',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '05/10/2020',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AP/1133611P/S/2020/000119',
#   'pFromTrxDate': '17/06/2020',
#   'label': 'STR',
#   'NeoId': 19073325},
#  {'pOffence': 'Drugs trafficking',
#   'pSumInsured': '668461.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '10/03/2017',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '30576.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-8e8e261a-7602-4b5e-943a-8dc81f237361',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '23/02/2017',
#   'pRecordID': 'CA/079/S/2017/000002',
#   'pFromTrxDate': '23/02/2017',
#   'label': 'STR',
#   'NeoId': 14745140},
#  {'uid': 'r-b8da089e-e189-41d1-af95-ba1ed89093cd',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'PULAU PINANG',
#   'pTrxAmount': '82736.05',
#   'pReportDate': '13/12/2017',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '29/11/2017',
#   'pRecordID': 'AN/001/S/2017/002502',
#   'pFromTrxDate': '29/09/2017',
#   'label': 'STR',
#   'NeoId': 14711225},
#  {'uid': 'r-88f4cae3-ee88-471e-b957-dff5ce220191',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'PULAU PINANG',
#   'pTrxAmount': '45633.39',
#   'pReportDate': '07/04/2017',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '29/03/2017',
#   'pRecordID': 'AN/001/S/2017/000882',
#   'pFromTrxDate': '15/02/2017',
#   'label': 'STR',
#   'NeoId': 14709613},
#  {'uid': 'r-07872f7d-5a6a-44f0-b895-82d7a04d6cbe',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'SELANGOR',
#   'pTrxAmount': '29510.36',
#   'pReportDate': '16/02/2017',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '23/01/2017',
#   'pRecordID': 'AN/001/S/2017/000520',
#   'pFromTrxDate': '19/12/2016',
#   'label': 'STR',
#   'NeoId': 14709252},
#  {'uid': 'r-a517c82a-de6b-4f23-a600-9f9679fa556d',
#   'pOffence': 'Money Laundering',
#   'pStateId': 'PULAU PINANG',
#   'pTrxAmount': '29510.36',
#   'pReportDate': '16/02/2017',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '23/01/2017',
#   'pRecordID': 'AN/001/S/2017/000499',
#   'pFromTrxDate': '19/12/2016',
#   'label': 'STR',
#   'NeoId': 14709231},
#  {'uid': 'r-9dc0e104-ec51-4ebf-acb3-212cd7b7690c',
#   'pOffence': 'Unlawful possession/dealing of controlled/scheduled items',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '32441.7',
#   'pReportDate': '05/03/2020',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Designated Payment Instruments Issuers',
#   'pToTrxDate': '12/02/2020',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AL/002/S/2020/000081',
#   'pFromTrxDate': '29/01/2020',
#   'label': 'STR',
#   'NeoId': 17958008},
#  {'uid': 'r-0f4588b2-2a26-4481-8a7a-f21d42b3ed4d',
#   'pOffence': 'Drugs trafficking',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '2522760.76',
#   'pReportDate': '12/02/2020',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Designated Payment Instruments Issuers',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '20/01/2020',
#   'pRecordID': 'AL/002/S/2020/000035',
#   'pFromTrxDate': '24/01/2015',
#   'label': 'STR',
#   'NeoId': 17581151},
#  {'uid': 'r-93fcb58b-e2c5-45fc-9327-e5002e971007',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '75387.36',
#   'pReportDate': '17/06/2015',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '05/02/2015',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2015/001196',
#   'pFromTrxDate': '13/01/2015',
#   'label': 'STR',
#   'NeoId': 14696780},
#  {'uid': 'r-2ed9441a-167b-4f27-be2e-8890595b218a',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '30005.0',
#   'pReportDate': '08/08/2018',
#   'pRecordTypeID': 'STR Money changer',
#   'pAttempted': 'N',
#   'pToTrxDate': '08/08/2018',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': '117/PP/0053/L/S/2018/000021',
#   'pFromTrxDate': '08/08/2018',
#   'label': 'STR',
#   'NeoId': 14386297},
#  {'uid': 'r-f92f2ad5-4bc2-4e6a-a98c-658b77702613',
#   'pOffence': 'Money Laundering',
#   'pSumInsured': '640000.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '17/06/2019',
#   'pRecordTypeID': 'STR Insurance',
#   'pAttempted': 'N',
#   'pPremiumAmount': '256000.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/008/S/2019/000017',
#   'pFromTrxDate': '17/04/2019',
#   'label': 'STR',
#   'NeoId': 14734485},
#  {'uid': 'r-e5eebe85-2835-41be-84d1-f9940551042a',
#   'pOffence': 'Money Laundering',
#   'pSumInsured': '89250.0',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '29/04/2020',
#   'pRecordTypeID': 'STR Insurance',
#   'pAttempted': 'N',
#   'pPremiumAmount': '85000.0',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'CA/008/S/2020/000092',
#   'pFromTrxDate': '06/03/2020',
#   'label': 'STR',
#   'NeoId': 17959224},
#  {'pOffence': 'Unknown',
#   'pSumInsured': '5000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '28/05/2015',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '4000.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-dc9bbdf2-09d8-4028-8afb-44f9b0d53a93',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '05/05/2014',
#   'pRecordID': 'CA/047/S/2015/000156',
#   'pFromTrxDate': '05/05/2014',
#   'label': 'STR',
#   'NeoId': 14741809},
#  {'pOffence': 'Money Laundering',
#   'pSumInsured': '0.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '19/04/2019',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '1000000.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-8c9b2494-dc26-4657-aeae-6e8fe38eab4b',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '28/02/2019',
#   'pRecordID': 'CA/026/S/2019/000022',
#   'pFromTrxDate': '28/02/2019',
#   'label': 'STR',
#   'NeoId': 14740822},
#  {'uid': 'r-554ce5f7-0945-4814-bc17-63cf2a030b27',
#   'pOffence': 'Unknown',
#   'pStateId': 'JOHOR',
#   'pTrxAmount': '0.0',
#   'pReportDate': '30/05/2017',
#   'pRecordTypeID': 'STR Unit Trust Mgmt Company',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '09/05/2017',
#   'pRecordID': 'AJ/069/S/2017/000006',
#   'pTotalFund': '3700000.0',
#   'pFromTrxDate': '18/04/2017',
#   'label': 'STR',
#   'NeoId': 14676475},
#  {'pOffence': 'Unknown',
#   'pSumInsured': '49900.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '17/10/2018',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '49900.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-2554fbf5-3247-4239-b979-d536655f67ca',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '18/09/2018',
#   'pRecordID': 'CA/023/S/2018/000029',
#   'pFromTrxDate': '18/09/2018',
#   'label': 'STR',
#   'NeoId': 14740520},
#  {'uid': 'r-45c40788-9774-448b-bef9-fcf11c77d05b',
#   'pOffence': 'Unknown',
#   'pStateId': 'SARAWAK',
#   'pTrxAmount': '39588.0',
#   'pReportDate': '09/01/2014',
#   'pRecordTypeID': 'STR Remittance Company',
#   'pAttempted': 'N',
#   'pToTrxDate': '07/10/2013',
#   'pBranchId': 'UNKNOWN',
#   'pRecordID': 'AN/001/S/2013/004554',
#   'pFromTrxDate': '05/09/2013',
#   'label': 'STR',
#   'NeoId': 14689749},
#  {'uid': 'r-ab7b73fe-d6b0-4985-b83f-bdf9e3d707c5',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '100000.0',
#   'pReportDate': '27/09/2016',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '29/08/2016',
#   'pRecordID': 'DA/002/S/2016/007105',
#   'pFromTrxDate': '29/08/2016',
#   'label': 'STR',
#   'NeoId': 14762979},
#  {'uid': 'r-dabbce2a-3b05-4330-bf32-9b8c8c8f69af',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '58155150.0',
#   'pReportDate': '01/02/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '30/09/2017',
#   'pRecordID': 'DA/002/S/2017/007282',
#   'pFromTrxDate': '01/10/2015',
#   'label': 'STR',
#   'NeoId': 14772187},
#  {'uid': 'r-7c961945-b0c5-473a-8868-e2beb4944ee3',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '108285.0',
#   'pReportDate': '02/02/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '13/12/2017',
#   'pRecordID': 'DA/002/S/2018/000366',
#   'pFromTrxDate': '13/12/2017',
#   'label': 'STR',
#   'NeoId': 14773001},
#  {'pOffence': 'Money Laundering',
#   'pSumInsured': '100000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '03/10/2018',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '100000.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-80264223-5068-495b-95dd-11f1e9105231',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '18/09/2018',
#   'pRecordID': 'CA/021/S/2018/000621',
#   'pFromTrxDate': '18/09/2018',
#   'label': 'STR',
#   'NeoId': 14739722},
#  {'pOffence': 'Unknown',
#   'pSumInsured': '1000000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '06/07/2017',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '85245.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-b9e3ee66-80ac-427d-a5e7-7b4d529a06d4',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '29/06/2017',
#   'pRecordID': 'CA/047/S/2017/000113',
#   'pFromTrxDate': '29/06/2017',
#   'label': 'STR',
#   'NeoId': 14742285},
#  {'pOffence': 'Money Laundering',
#   'pSumInsured': '120000.0',
#   'pTrxAmount': '0.0',
#   'pReportDate': '08/11/2018',
#   'pRecordTypeID': 'STR Insurance',
#   'pPremiumAmount': '120000.0',
#   'pBranchId': 'UNKNOWN',
#   'uid': 'r-907ebf70-23a9-4cff-9999-a5b56c6bbf9e',
#   'pStateId': 'UNKNOWN',
#   'pAttempted': 'N',
#   'pToTrxDate': '05/11/2018',
#   'pRecordID': 'CA/021/S/2018/000764',
#   'pFromTrxDate': '05/11/2018',
#   'label': 'STR',
#   'NeoId': 14739865},
#  {'uid': 'r-c052e1a5-9e0d-47bf-94dc-f6d3987a6a0b',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '55000.0',
#   'pReportDate': '31/12/2015',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '02/12/2015',
#   'pRecordID': 'DA/002/S/2015/007855',
#   'pFromTrxDate': '02/12/2015',
#   'label': 'STR',
#   'NeoId': 14756193},
#  {'uid': 'r-dd5bd961-3a4b-44ca-a85c-8707a44d52f8',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '0.0',
#   'pReportDate': '22/08/2015',
#   'pAttempted': 'N',
#   'pRecordTypeID': 'STR Casino',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '03/07/2015',
#   'pRecordID': 'DA/002/S/2015/004711',
#   'pFromTrxDate': '03/07/2015',
#   'label': 'STR',
#   'NeoId': 14753197},
#  {'uid': 'r-cbd61726-5050-4ed6-86af-ba497aae81a1',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '533005.0',
#   'pReportDate': '29/05/2019',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '28/04/2019',
#   'pRecordID': 'DA/002/S/2019/002123',
#   'pFromTrxDate': '27/04/2019',
#   'label': 'STR',
#   'NeoId': 14780466},
#  {'uid': 'r-78c38b09-7af2-4268-97ee-d865eda9404f',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '746505.0',
#   'pReportDate': '05/04/2019',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '24/02/2019',
#   'pRecordID': 'DA/002/S/2019/001276',
#   'pFromTrxDate': '24/02/2019',
#   'label': 'STR',
#   'NeoId': 14779643},
#  {'uid': 'r-7d22e6ae-1dd1-46a8-ab75-bbb622352509',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '1774410.0',
#   'pReportDate': '28/03/2018',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '04/03/2018',
#   'pRecordID': 'DA/002/S/2018/001674',
#   'pFromTrxDate': '03/03/2018',
#   'label': 'STR',
#   'NeoId': 14774281},
#  {'uid': 'r-4c03cd66-de9f-4785-896c-b4bdce52acd4',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '176930.0',
#   'pReportDate': '26/04/2016',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '19/03/2016',
#   'pRecordID': 'DA/002/S/2016/002543',
#   'pFromTrxDate': '18/03/2016',
#   'label': 'STR',
#   'NeoId': 14758625},
#  {'uid': 'r-f8791c97-bc6f-4819-80b1-eab8e4c9b9df',
#   'pOffence': 'Unknown',
#   'pStateId': 'UNKNOWN',
#   'pTrxAmount': '69780.0',
#   'pReportDate': '29/03/2016',
#   'pRecordTypeID': 'STR Casino',
#   'pAttempted': 'N',
#   'pBranchId': 'UNKNOWN',
#   'pToTrxDate': '20/02/2016',
#   'pRecordID': 'DA/002/S/2016/001496',
#   'pFromTrxDate': '20/02/2016',
#   'label': 'STR',
#   'NeoId': 14757622},
#  ...]

# %% [markdown]
# ### Build dict and extract info from ES

# %%
#build neoId to es uid dict
neoIdtoUidDict = {node['NeoId']:node['uid']
                 for node in tempGraphDict['nodes'] if node['label'] in ['Entity']}

#neoId to Str Amount Dict
neoIdtoStrAmountDict = dict([(i['NeoId'], float(i['pTrxAmount'])) for i in tempGraphDict['nodes'] if i['label'] == 'STR'])

#neoId to Ctr Amount Dict
accountInfo = [i for i in tempGraphDict['nodes'] if i['label'] == 'Account']
yearCol = ['p' + str(i) for i in range(2006, 2021)]
neoIdtoCtrAmountDict = dict([(i['NeoId'], sum([float(i[col]) for col in i.keys() if col in yearCol])) for i in accountInfo])
#build neoId to RI dict
neoIdtoRIDict = {i['NeoId']:i['pReportingIns'] for i in accountInfo}

#neoIds of str node
strNodeNeoIds = [i['NeoId'] for i in tempGraphDict['nodes'] if i['label'] == 'STR']

#details of str node
strNodeDetails = [i for i in tempGraphDict['nodes'] if i['label'] == 'STR']

#str uid to str reportID
strNeoIdtoReportID = {node['NeoId']:node['pRecordID'] for node in strNodeDetails}

# %%
#get all neoId from all networks
esUidList = list(neoIdtoUidDict.values())

# indexName = 'report_db'
# queryAll = {'match_all':{}}
# queryAll = {'match':{'uid':'e-7a83f99e-17ab-4f78-96f1-3375286dbfa0'}}
# res = es.search(index = indexName, size = 1, body = {'query':queryAll})

#extract info/details for each entity in entity_db
#query es
indexName = 'entity_db'
esEntityResult = multiSearch('uid', esUidList)

#uid to occupation
uidToOccupationDict = {}
for no, i in enumerate(esEntityResult):
    if i:
        if 'occupation' in i[0]['_source'].keys():
            uidToOccupationDict[i[0]['_source']['uid']] = ','.join(i[0]['_source']['occupation'])

reportIDList = strNeoIdtoReportID.values()

#query es to get str info
indexName = 'detail_str'
esStrResult = multiSearch('record_id', reportIDList)

#str report ID to get desc
strReportIDtoDesc = {node[0]['_source']['record_id']:node[0]['_source']['suspicion_desc'] for node in esStrResult
                    if node}

# %%
#uid to id_list
uidToIDListDict = {}
for no, i in enumerate(esEntityResult):
    if i:
        if 'id_list' in i[0]['_source'].keys():
            uidToIDListDict[i[0]['_source']['uid']] = ','.join(i[0]['_source']['id_list'])

# %%
reportIDList = strNeoIdtoReportID.values()

#query es to get str info
indexName = 'detail_str'
esStrResult = multiSearch('record_id', reportIDList)

#str report ID to get desc
strReportIDtoDesc = {node[0]['_source']['record_id']:node[0]['_source']['suspicion_desc'] for node in esStrResult
                    if node}

# %% [markdown]
# ### Build table - validation purpose

# %%
dfNetworkScam = pd.DataFrame()

#list of neoIds for all nodes for each network
dfNetworkScam['NeoIds'] = [i for i in subGraphsList]

#get all transaction id for each network
dfNetworkScam['TransIds'] = dfNetworkScam['NeoIds'].map(lambda x:[i['transId'] for i in tempGraphDict['links'] 
                                                                 if i['source'] in x and i['target'] in x])

# %%
#check if str connected to each network contains scam/fraud
def checkIfScam(neoIdArray):
    offenceList = []
    for array in neoIdArray:
        tempList = []
        strList = set(array) & set(strNodeNeoIds)
        for strId in strList:
            tempList.append([i['pOffence'] for i in strNodeDetails if i['NeoId'] == strId][0])
        offenceList.append(tempList)
    #check if scam/fraud in related str
#     print(offenceList)
    scamList = []
    for offence in offenceList:
        temp = [True for i in offence if re.search("scam|fraud", str(i), re.I)]
        if len(temp)>0:
            scamList.append(True)
        else:
            scamList.append(False)
    return scamList

dfNetworkScam['IsScamFraud'] = checkIfScam(dfNetworkScam['NeoIds'].values)

#target neoIds
dfNetworkScam['TargetNeoIds'] = dfNetworkScam['NeoIds'].map(lambda x:set([i for i in x if i in neoIdtoNameDictTargetOnly.keys()]))

#target names
dfNetworkScam['TargetNames'] = dfNetworkScam['TargetNeoIds'].map(lambda x:[neoIdtoNameDictTargetOnly[i] for i in x])

# %%
nameList = dfNetworkScam[dfNetworkScam['IsScamFraud']]['TargetNames']
uniqueNameList = set([j for i in nameList for j in i])
print("Number of names found in network related to scam/fraud: %s"%len(uniqueNameList))
print("Number of network related to scam/fraud: %s"%sum(dfNetworkScam['IsScamFraud']))
# Out:
# Number of names found in network related to scam/fraud: 48
# Number of network related to scam/fraud: 20

# %%
#the only name left out
set(neoIdtoNameDictTargetOnly.values()).difference(uniqueNameList)
# Out:
# {'NORZERIN BINTI MISKAM'}

# %%
tempDf = dfNetworkScam[dfNetworkScam['TargetNames'].map(lambda x: True if 'NORZERIN BINTI MISKAM' in x else False)].copy()
tempDf
# Out:
#                                                NeoIds  \
# 14  {16950017, 11893795, 16137924, 16929763, 41719...
#
#                                              TransIds  IsScamFraud  \
# 14  [11566431, 11566430, 19286470, 19286469, 14859...        False
#
#    TargetNeoIds              TargetNames
# 14   {11109587}  [NORZERIN BINTI MISKAM]

# %%
#check if str connected to each network contains scam/fraud
def checkIfScam(neoIdArray):
    offenceList = []
    for array in neoIdArray:
        tempList = []
        strList = set(array) & set(strNodeNeoIds)
        for strId in strList:
            tempList.append([i['pOffence'] for i in strNodeDetails if i['NeoId'] == strId][0])
        offenceList.append(tempList)
    #check if scam/fraud in related str
    print(offenceList)
checkIfScam(tempDf['NeoIds'].values)
# Out:
# [[]]

# %%
for nodeId in tempDf['NeoIds'].values[0]:
    print([i for i in tempGraphDict['nodes'] if i['NeoId'] == nodeId][0])
    print('\n')
# Out:
# {'uid': 'c-1726b7ef-e393-4b11-8874-df6848bf0da4', 'pContactInfo': '0033723333', 'label': 'Contact', 'NeoId': 16950017}
#
#
# {'uid': 'e-fa38a8c4-1114-4bc6-9625-377f12064102', 'pOccupation': ['Police Officer'], 'pName': 'MONA ARI', 'pNameList': ['MONA ARI'], 'pCountry': ['MALAYSIA'], 'pIdList': ['RF130701', '770104135358', 'K0387972'], 'contact_list': ['00355145280', '0193749693', '0197539912', '0355145231', '0176236761'], 'pOccupationDesc': [], 'label': 'Entity', 'NeoId': 11893795}
#
#
# {'uid': 'c-3a32a00a-9203-43ba-8ed5-87190931d320', 'pContactInfo': '0140091546770000', 'label': 'Contact', 'NeoId': 16137924}
#
#
# {'uid': 'c-c3079f9e-6043-4b9b-9666-075c86fe9b40', 'pContactInfo': '0176236761', 'label': 'Contact', 'NeoId': 16929763}
#
#
# {'uid': 'a-f5ae56df-cb2a-4622-a96b-d6f769ddda66', 'pTrxTypeId': 'Aggregate', 'pTotalAmount': 89937.2, 'pAccountNo': '0740020009396', 'pStateId': 'SELANGOR', 'pAccountType': 'Savings Account', 'pReportingIns': 'AmIslamic Bank Berhad.', 'p2008': 89937.2, 'pBranchId': 'SHAH ALAM SEC 13', 'label': 'Account', 'NeoId': 4171908}
#
#
# {'p2013': 60000.0, 'uid': 'a-2ecfed68-167f-4716-b63f-cd7a90f43362', 'pTotalAmount': 60000.0, 'pAccountNo': '112103043823', 'pStateId': 'UNKNOWN', 'pAccountType': 'Savings Account', 'pReportingIns': 'Malayan Banking Berhad.', 'pBranchId': 'UNKNOWN', 'label': 'Account', 'NeoId': 7381706}
#
#
# {'uid': 'c-14f796ff-660e-465e-820e-c1de9b30461a', 'pContactInfo': '0123531744033342', 'label': 'Contact', 'NeoId': 16797228}
#
#
# {'uid': 'e-10eb3b0c-0337-4675-81c4-eaa3f6b1e983', 'pOccupation': [], 'pName': 'NORZERIN BINTI MISKAM', 'pNameList': ['NORZERIN BINTI MISKAM', 'NORZERIN BINTI MISKAN'], 'pCountry': ['MALAYSIA'], 'pIdList': ['800525015690'], 'contact_list': ['0140091546770000', '0123531744033342', '0033723333'], 'pOccupationDesc': [], 'label': 'Entity', 'NeoId': 11109587}
#
#
# {'uid': 'c-8b22826c-8677-4865-9225-1c55984925dd', 'pContactInfo': '0193749693', 'label': 'Contact', 'NeoId': 16469855}
#
#
# {'uid': 'e-8a875a29-4167-4326-a047-c8c209ea8d05', 'pOccupation': ['Police Officer', 'Government', 'Officer', 'Executive', 'Clerk', 'Administrator', 'Detective', 'Others', 'Retiree', 'Technician', 'Unknown', 'Secretary', 'General Worker'], 'pName': 'POLIS DI RAJA MALAYSIA TAMPOI BRANCH', 'pNameList': ['POLIS DIRAJA MALAYSIA', 'POLIS DIRAJA MALAYSIA BUKIT AMAN', 'SM 0262 POLIS DIRAJA MALAYSIA', 'POLIS DIRAJA DI MALAYSIA', 'POLIS DI RAJA MALAYSIA', 'POLIS DI RAJA MALAYSIA TAMPOI BRANCH'], 'pCountry': ['MALAYSIA'], 'pIdList': [], 'contact_list': ['0326222222', '0126625666'], 'pOccupationDesc': ['GOVERNMENT AGENCY - POLICE - INSPECTOR & ABOVE', 'ADMINISTRATIVE AND EXECUTIVE', 'GENERAL OFFICE CLERKS', 'POLICE/ARMY/ENFORC/SAFETY/SEC / GOVERNMENT SECTOR', 'ASSISTANT SUPERINTENDENT', 'LANCE CORPORAL', 'POLICE PERSONNEL', 'POLICE/ARMY/ENFORC/SAFETY/SEC', 'COPERAL', 'CLERK', 'UNITED NATION (PERSATUAN BANGSA BANGSA BERSATU)', 'POLICE OFFICER', 'INSPECTOR', 'DEPUTY OFFICER', 'RM5,000 TO RM5,999', 'INCOME: RM4,000 TO RM4,999', 'POLICE', 'SERGEANT', 'PUBLIC ADMINISTRATION AND DEFENCE', 'EMPLOYED AT POLIS DIRAJA MALAYSIA', 'GOVERNMENT SERVANT', 'GOVERNMENT AGENCY - POLICE - ASP & ABOVE', 'PROFESSIONAL POLICE INSPECTORS AND DETECTIVES', 'GOVERNMENT AGENCY - POLICE - SERGEANT & BELOW', 'GOVERNMENT AGENCY - POLICE - SEGEANT & BELOW', 'PUBLIC ADMIN & DEFENCE', 'POLICE TRAFFIC', 'CONSTABLE', 'LANS KOPERAL', 'KOPERAL', 'BHG KOMUNIKASI JAB LOGISTIK / PEJ POLIS BUKIT AMAN', 'CAW JENAYAH D7 IPD TIMUR LAUT, PULAU PINANG', 'ASSISTANT', 'PEMBANTU TADBIR', 'CHIEF INSPECTOR', 'PENOLONG PENGUASA POLIS', 'TIMBALAN PENGUASA', 'POLICEMAN', '1008 - GOVERNMENT AGENCY - POLICE - INSPECTOR & ABOVE', 'BAHAGIAN TEKNIKAL', 'PENOLONG PESURUHJAYA POLIS', 'SARJAN', 'CHIEF INSPECTOR OF POLICE', 'UNIFORMED SERVICES', 'LANCE KOPRAL', 'PEKERJA RENDAH AWAM', 'KONSTABEL', 'CORPORAL', 'INSPECTOR POLICE', 'UNKNOWN', 'PUBLIC SERVANT', 'PASUKAN GERAKAN MARIN IPD TAWAU', 'CONSTABLE IN POLICE FORCE', 'POLICEWOMAN', 'STATE HEAD OF CRIME BRANCH', 'SENIOR ASSISTANT COMMISSIONER II', 'POLICE SENIOR OFFICER', 'KELANTAN POLICE CHIEF', 'BAHAGIAN PENDAFTRAAN & KANTIN POLIS', 'KETUA POLIS CAWANGAN SG. PETANI', 'SERGEANT MAJOR', 'ASSISTANT POLICE SUPERINTENDENT', 'DEPUTY SUPERINTENDENT', 'ASSISTANT SUPERINTENDENT OF POLICE', 'DEPUTY SUPERINTENDENT OF POLICE', 'N/A', 'FINANCE OFFICER'], 'label': 'Entity', 'NeoId': 9123992}
#
#
# {'p2014': 95003.0, 'uid': 'a-ed0100b4-0bf3-46e1-b79e-c38aae57c9ed', 'pTrxTypeId': 'Aggregate', 'pTotalAmount': 95003.0, 'pAccountNo': '162106974640', 'pStateId': 'SELANGOR', 'pAccountType': 'Savings Account', 'pReportingIns': 'Maybank Islamic Berhad', 'pBranchId': 'SHAH ALAM', 'label': 'Account', 'NeoId': 6980442}
#
#
# {'uid': 'a-1c0460bc-537d-4a56-98e3-57a4b83b5385', 'p2015': 95000.0, 'pTotalAmount': 95000.0, 'pTrxTypeId': 'Cash Contra Credit', 'pAccountNo': '37493001626', 'pStateId': 'SELANGOR', 'pAccountType': 'Financing Account', 'pReportingIns': 'Hong Leong Islamic Bank Bhd', 'pBranchId': 'JALAN 227C', 'label': 'Account', 'NeoId': 6001438}
#
#
# {'uid': 'a-b3e47ce0-9d2e-45ec-9780-36f8533ae864', 'p2015': 91810.0, 'pTrxTypeId': 'Aggregate', 'pTotalAmount': 91810.0, 'pAccountNo': '910194849420', 'pStateId': 'SELANGOR', 'pAccountType': 'Current Account', 'pReportingIns': 'Standard Chartered Bank Malaysia Berhad', 'pBranchId': 'STANDARD CHARTERED BANK PUCHONG', 'label': 'Account', 'NeoId': 2784191}

# %%
#extract ids
targetNeoIdList = [j for i in dfNetworkScam[dfNetworkScam['IsScamFraud']]['TargetNeoIds'] for j in i]
tempIdList = [i['pIdList'] for i in tempGraphDict['nodes'] if i['NeoId'] in targetNeoIdList]
targetIdList = [j for i in tempIdList for j in i]
#export to csv
import csv
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-03_ScamId.csv"
# with open(filename, "w") as f:
#     writer = csv.writer(f)
#     writer.writerows(targetNeoIdList)
pd.Series(targetIdList).to_csv(filename, index = False)

# %% [markdown]
# ### General Characteristics

# %%
# dfNetworkScam = pd.DataFrame()

# #list of neoIds for all nodes for each network
# dfNetworkScam['NeoIds'] = [i for i in subGraphsList]

# #get all transaction id for each network
# dfNetworkScam['TransIds'] = dfNetworkScam['NeoIds'].map(lambda x:[i['transId'] for i in tempGraphDict['links'] 
#                                             if i['source'] in x and i['target'] in x])

#number of nodes for each network
dfNetworkScam['NumNodes'] = [len(i) for i in subGraphsList]

#number of connection for each network
dfNetworkScam['NumConnection'] = [len(i) - 1 for i in subGraphsList]

#calculate number of Str
dfNetworkScam['NumStr'] = dfNetworkScam['NeoIds'].map(lambda x:len(set(x) & set(strNodeNeoIds)))

#get strAmount for each neoIds and sum it for each network
dfNetworkScam['StrAmount'] = dfNetworkScam['NeoIds'].map(lambda x:sum([neoIdtoStrAmountDict.get(i, 0) for i in x]))

#get ctrAmount for each neoIds and sum it for each network
dfNetworkScam['CtrAmount'] = dfNetworkScam['NeoIds'].map(lambda x:sum([neoIdtoCtrAmountDict.get(i, 0) for i in x]))

#get RI for each network
dfNetworkScam['RIList'] = dfNetworkScam['NeoIds'].map(lambda x:[i for i in [neoIdtoRIDict.get(i, "") for i in x] if i!=''])

#target neoIds
dfNetworkScam['TargetNeoIds'] = dfNetworkScam['NeoIds'].map(lambda x:set([i for i in x if i in neoIdtoNameDictTargetOnly.keys()]))

#target names
dfNetworkScam['TargetNames'] = dfNetworkScam['TargetNeoIds'].map(lambda x:[neoIdtoNameDictTargetOnly[i] for i in x])

#target es uid
dfNetworkScam['TargetESuid'] = dfNetworkScam['TargetNeoIds'].map(lambda x:set([neoIdtoUidDict[i] 
                                                                   for i in x]))

#number of targets for each network based on unique id
dfNetworkScam['NumberTargetNeoId'] = dfNetworkScam['TargetNeoIds'].map(lambda x:len(set(x)))

#number of targets for each network based on unique names
dfNetworkScam['NumberTargetNames'] = dfNetworkScam['TargetNames'].map(lambda x:len(set(x)))

#check if target shares contact for each network
contactTransInfo = [i for i in tempGraphDict['links'] if i['type'] == 'HAS_CONTACT'] 
def checkTargetSharingContact(transIdArray, targetNeoIdArray):
    resultBool = []
    for i in zip(transIdArray, targetNeoIdArray):
        #loop through contact transID if it is found in transID for each row
        targetArray = [trans['target'] for trans in contactTransInfo 
                       if trans['transId'] in i[0] and trans['source'] in i[1]]
        
        #1 if has shared contact else 0
        if len(set(targetArray)) != len(targetArray):
            resultBool.append(1)
        else:
            resultBool.append(0)          
    return resultBool

dfNetworkScam['TargetSharingContact'] = checkTargetSharingContact(dfNetworkScam['TransIds'].values,
                                                                  dfNetworkScam['TargetNeoIds'].values)

# %%
dfNetworkScam.columns
# Out:
# Index(['NeoIds', 'TransIds', 'IsScamFraud', 'TargetNeoIds', 'TargetNames',
#        'NumNodes', 'NumConnection', 'NumStr', 'StrAmount', 'CtrAmount',
#        'TargetESuid', 'NumberTargetNeoId', 'NumberTargetNames',
#        'TargetSharingContact'],
#       dtype='object')

# %%
dfNetworkScam[dfNetworkScam['IsScamFraud']]['NumberTargetNames'].value_counts()
# Out:
# 1     18
# 2      1
# 33     1
# Name: NumberTargetNames, dtype: int64

# %%
# #get address from es
# esUidList = list(neoIdtoUidDict.values())

# #see if any entities (included targets) who share common address
# #query es
# indexName = 'entity_db'
# addressResult = multiSearch('uid', esUidList)

def checkTargetSharingAddress(esUidArray):
    resultArray = []
    #for each list of target uids
    for uidArray in esUidArray:
        addressDict = {}
        cleanAddressArray = []
        addressArray = [(uid, uidToAddressDict[uid]) for uid in uidArray if uid in uidToAddressDict.keys()]
        #clean and standardize each list of address for each uid
        regexSpecialChar = '\/|\,|\:|\(|\)|\?|\*|\-|\[|\]|\.|\+|\&|\=|\%|\-'
        for i in addressArray:
            cleanAddress = set([re.sub("\s+", " ", re.sub(regexSpecialChar, '', j.lower())) for j in i[1]])
            addressDict[i[0]] = cleanAddress
            cleanAddressArray.append(cleanAddress)
            
        #get count for each unique address
        addressCountDict = dict(pd.Series([j for i in cleanAddressArray for j in i]).value_counts())
        sharedAddressList = [i for i, j in addressCountDict.items() if j > 1]
        
        #if sharedAddressList is not empty
        if len(sharedAddressList)!=0:
            for sharedAddress in sharedAddressList:
                uidList = []
                for i,j in addressDict.items():
                    if sharedAddress in j:
                        uidList.append(i)
                        commonAddress = sharedAddress
            resultArray.append((uidList, 1, commonAddress))
        else:
            resultArray.append(('', 0, ''))
        
    return resultArray

#uid to address dict
#only 518 uid can get address - len(uidToAddressDict)
# uidToAddressDict = {i[0]['_source']['uid']: i[0]['_source']['detail']['ADDRESS'] for i in addressResult
#                    if 'ADDRESS' in i[0]['_source']['detail'].keys()}
uidToAddressDict = {}
for no, i in enumerate(esEntityResult):
    if i:
        if 'ADDRESS' in i[0]['_source']['detail'].keys():
            uidToAddressDict[i[0]['_source']['uid']] = i[0]['_source']['detail']['ADDRESS']
                
targetSharingAddressTuple = checkTargetSharingAddress(dfNetworkScam['TargetESuid'].values)

#1 if targets share address, else 0
dfNetworkScam['TargetSharingAddress'] = [i[1] for i in targetSharingAddressTuple]

#list of target uid sharing address
dfNetworkScam['TargetUidSharingAddress'] = [i[0] for i in targetSharingAddressTuple]

#common address if targets share
dfNetworkScam['CommonAddress'] = [i[2] for i in targetSharingAddressTuple]

#targets sharing contact/address 
dfNetworkScam['TargetSharingContactOrAddress'] = dfNetworkScam.apply(lambda x:0 if x['TargetSharingAddress'] == 0 
                                                                       and x['TargetSharingContact'] == 0
                                                                      else 1, axis = 1)
# Out:
# D:\Users\figohjs\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
#get target occupation
def getTargetOccupation(esUidArray):
    occupationList = []
    for uidArray in esUidArray:
        tempList = [uidToOccupationDict[i] for i in uidArray if i in uidToOccupationDict]
        occupationList.append(','.join([i for i in tempList if i]))
    return occupationList
dfNetworkScam['TargetOccupationList'] = getTargetOccupation(dfNetworkScam['TargetESuid'].values)

# %%
dfNetworkScam['TargetSharingContactOrAddress'].value_counts()
# Out:
# 0    145
# 1      6
# Name: TargetSharingContactOrAddress, dtype: int64

# %%
dfNetworkScam['IsScamFraud'].value_counts()
# Out:
# False    131
# True      20
# Name: IsScamFraud, dtype: int64

# %%
len(addressResult)
# Out:
# 105566

# %% [markdown]
# ### Network perspective

# %%
Latex(r"""
\begin{equation}
Density = \frac{C}{n(n-1)}
\end{equation}
\begin{align}
\text{where } &\text{C - actual connection,}
\newline
&\text{n - number of nodes}
\end{align}
""")
# Out:
# \begin{equation}
# Density = \frac{C}{n(n-1)}
# \end{equation}
# \begin{align}
# \text{where } &\text{C - actual connection,}
# \newline
# &\text{n - number of nodes}
# \end{align}

# %%
def calculateDensity(x):
    numCon = x['NumConnection']
    numNode = x['NumNodes']
    return numCon/(numNode*(numNode -1))

#calculate density for each network
dfNetworkScam['Density'] = dfNetworkScam.apply(calculateDensity, axis = 1)

#degree centrality
#assumption: important node has many connection d(i) = number of edges/no.of nodes - 1
neoIdToDC = nx.degree_centrality(networkGraph)

#degree centrality for each node for each network
dfNetworkScam['DCList'] = dfNetworkScam['NeoIds'].map(lambda x:[neoIdToDC.get(i,0) for i in x])

#get max degree centrality for each network
dfNetworkScam['MaxDC'] = dfNetworkScam['DCList'].map(max)

# %%
dfNetworkScam.columns
# Out:
# Index(['NeoIds', 'TransIds', 'IsScamFraud', 'TargetNeoIds', 'TargetNames',
#        'NumNodes', 'NumConnection', 'NumStr', 'StrAmount', 'CtrAmount',
#        'TargetESuid', 'NumberTargetNeoId', 'NumberTargetNames',
#        'TargetSharingContact', 'Density', 'DCList', 'MaxDC',
#        'TargetSharingAddress', 'TargetUidSharingAddress', 'CommonAddress',
#        'TargetSharingContactOrAddress'],
#       dtype='object')

# %%
#save df
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-15_ScamSubgraphsDF.csv"
dfNetworkScam.to_csv(filename, index = False)

# %% [markdown]
# ### Further processing

# %% [markdown]
# ### 2021-03-21

# %%
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline

# %%
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-15_ScamSubgraphsDF.csv"

df = pd.read_csv(filename)

#convert str to list - export issue 
def colBeList(colArray, colName):
    result = []
    for colList in [i.replace("{", '').replace('}', '')\
                     .replace("[", '').replace(']', '')\
                    .replace("\'", '').split(',') for i in colArray]:
        if colName in ['NeoIds', 'TransIds', 'TargetNeoIds']:
            result.append([int(i.strip()) if i!='set()' and i!='' else '' for i in colList])
        else:
            result.append([i.strip() for i in colList])
    return result

colList = ['NeoIds', 'TransIds', 'TargetNeoIds']
for col in colList:
    if col in df.columns:
        df[col] = colBeList(df[col].values, col)

# %%
dfNetworkScam = df[df['IsScamFraud']].copy()
dfNetworkScam.shape
# Out:
# (20, 23)

# %%
dfScam.columns
# Out:
# Index(['NeoIds', 'TransIds', 'IsScamFraud', 'TargetNeoIds', 'TargetNames',
#        'NumNodes', 'NumConnection', 'NumStr', 'StrAmount', 'CtrAmount',
#        'TargetESuid', 'NumberTargetNeoId', 'NumberTargetNames',
#        'TargetSharingContact', 'Density', 'DCList', 'MaxDC',
#        'TargetSharingAddress', 'TargetUidSharingAddress', 'CommonAddress',
#        'TargetSharingContactOrAddress', 'TargetOccupationList', 'RIList'],
#       dtype='object')

# %%
scamNeoIdList = [j for i in dfScam['NeoIds'].values for j in i]
len(scamNeoIdList), len(set(scamNeoIdList))
# Out:
# (633324, 633324)

# %%
#get RI for each network for STR nodes
# dfNetworkScam['RIList'] = dfNetworkScam['NeoIds'].map(lambda x:[i for i in [neoIdtoRIDict.get(i, "") for i in x] 
#                                                                 if i!='' and i in strNodeNeoIds])

#uid to state dict
uidToState = {i['uid']:i['pStateId'] for i in accountInfo}

#uid to account type dict
uidToAccountType = {i['uid']:i['pAccountType'] for i in accountInfo}

#account neoid to uid dict
accountNeoIdtoUidDict = {node['NeoId']:node['uid']
                         for node in tempGraphDict['nodes'] if node['label'] in ['Account']}

# %%
scamUidList = [accountNeoIdtoUidDict[i] for i in scamNeoIdList if i in accountNeoIdtoUidDict.keys()]
len(scamUidList)
# Out:
# 455843

# %%
accountInfoDict = {i['uid']:i for i in accountInfo}

# %%
#account which are found in scam networks
accountInfo2 = [accountInfoDict[i] for i in scamUidList]

# %%
len(accountInfo), len(accountInfo2)
# Out:
# (497496, 455843)

# %%
#neoIdtoRIDict is from accountInfo
def countByState(neoIdArray):
    resultList = []
    for idArray in neoIdArray:
        countDict = defaultdict(int)
        for i in idArray:
            if i in neoIdtoRIDict.keys():
                uid = accountNeoIdtoUidDict[i]
                countDict[uidToState[uid]]+=1
        resultList.append(dict(countDict))
    return resultList

#neoIdtoRIDict is from accountInfo
def countByTrxType(neoIdArray):
    resultList = []
    for idArray in neoIdArray:
        countDict = defaultdict(int)
        for i in idArray:
            if i in neoIdtoRIDict.keys():
                uid = accountNeoIdtoUidDict[i]
                countDict[uidToAccountType[uid]]+=1
        resultList.append(dict(countDict))
    return resultList

# %%
#(RI, year):amount
resultList = []
for record in accountInfo2:
    #year, amount
    tempList = [(i, record[i]) for i in record if re.search("p\d{4}", i)]
    for i in tempList:
        resultList.append([record['pStateId'], record['pReportingIns'], record['pAccountType'], i[0], i[1]])

# %%
dfAccount = pd.DataFrame(resultList, columns = ['State', 'RI', 'AccountType', 'Year', 'Amount'])
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-19_ScamAccountSummary.csv"
dfAccount.to_csv(filename, index = False)

# %%
dfNetworkScam['AccTotalByState'] = countByState(dfNetworkScam['NeoIds'].values)

dfNetworkScam['AccTotalByTrxType'] = countByTrxType(dfNetworkScam['NeoIds'].values)

# %%
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-17_ScamSubgraphsDF.csv"
dfNetworkScam.to_csv(filename, index = False)

# %% [markdown]
# ### 2021-03-25

# %%
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-17_ScamSubgraphsDF.csv"

df = pd.read_csv(filename)

#convert str to list - export issue 
def colBeList(colArray, colName):
    result = []
    for colList in [i.replace("{", '').replace('}', '')\
                     .replace("[", '').replace(']', '')\
                    .replace("\'", '').split(',') for i in colArray]:
        if colName in ['NeoIds', 'TransIds', 'TargetNeoIds']:
            result.append([int(i.strip()) if i!='set()' and i!= '' else '' for i in colList])
        else:
            result.append([i.strip() for i in colList])
    return result

colList = ['NeoIds', 'TransIds', 'TargetNeoIds', 'TargetESuid']
for col in colList:
    if col in df.columns:
        df[col] = colBeList(df[col].values, col)

# %%
dfNetworkScam = df[df['IsScamFraud']].copy()
dfNetworkScam.shape
# Out:
# (20, 25)

# %%
#get all transaction id for each network
dfNetworkScam['ReportIds'] = dfNetworkScam['NeoIds'].map(lambda x:[strNeoIdtoReportID[i] for i in x if i in strNeoIdtoReportID.keys()])

dfNetworkScam['ReportDesc'] = dfNetworkScam['ReportIds'].map(lambda x:[strReportIDtoDesc[i] for i in x if i in strReportIDtoDesc])

# %%
dfNetworkScam['ReportDesc'][0][0]
# Out:
# 'THIS IS A REPORT OF SUSPECTED COUNTERFEIT SALES AND MERCHANT FRAUD. SEONG MUN KHIEW, 2090656347420678603 OWNS A PAYPAL ACCOUNT REGISTERED IN MALAYSIA.  SEONG?S ACCOUNT WAS CREATED ON AUGUST 1, 2015, AND HAS BEEN RECEIVING PAYMENTS FOR SELLING SUSPECTED COUNTERFEIT WATCHES ON HTTP://WWW.FASHIONACCIES.CO.IN. A REVIEW ON SEONG?S ACCOUNT FOUND THAT SEONG IS SELLING G-SHOCK WATCHES ON HTTP://WWW.BRANDEDWATCHFACTORY.COM. BOTH WEBSITES ARE LINKED VIA COMPUTER COOKIES AND PAYPAL BELIEVES HTTP://WWW.FASHIONACCIES.CO.IN IS A SHELL SITE TO COVER SEONG?S SUSPICIOUS ACTIVITY. FURTHER REVIEW FOUND THAT G-SHOCK WATCH ADVERTISED ON HTTP://WWW.BRANDEDWATCHFACTORY.COM IS ALSO FOUND ON SHELL WEBSITE UNDER: WATCHES-2013-01-17. PAYPAL BELIEVES THAT SEONG IS SELLING AND RECEIVING FUNDS FOR FAKE WATCHES SOLD ON HTTP://WWW.FASHIONACCIES.CO.IN. LATER, PAYPAL RECEIVED COMPLAINTS FROM THE BUYERS FOR ITEM NOT RECEIPT AND NOT AS DESCRIBED. DUE TO LACK OF SELLER?S RESPONSE, THE FUNDS WERE REVERSED TO COVER FOR BUYER?S LOSSES. TOTAL AGGREGATE DOLLAR AMOUNT RECEIVED IS $2,024.36 USD BETWEEN AUGUST 1, 2015 AND OCTOBER 13, 2015. A LIMITATION HAS BEEN PLACED ON THIS ACCOUNT BY PAYPAL?S FRAUD DEPARTMENT ON OCTOBER 14, 2015. THE USER IS NOT ABLE TO SEND, RECEIVE OR WITHDRAW ANY FUNDS. PAYPAL BELIEVES THE ACCOUNT HOLDER IS INVOLVED IN SELLING COUNTERFEIT GOODS. A CHECK ON SEONG?S NAME THROUGH WORLD CHECK (HTTPS://WWW.WORLD-CHECK.COM) DID NOT SHOW THAT SEONG IS INVOLVED IN ANY KIND OF SUSPICIOUS ACTIVITY. MORE DETAILS ARE AVAILABLE UPON REQUEST.'

# %%
def getTargetAge(esUidArray):
    ageList = []
    for uidArray in esUidArray:
        tempResult = []
        tempList = [uidToIDListDict[i] for i in uidArray if i in uidToIDListDict]
        for idList in tempList:
            tempId = [i for i in idList.split(',') if len(i) == 12 and re.search('\d{2}', i[:2])]
            if tempId:
                first2Digits = tempId[0][:2]
                if first2Digits[0] == '0':
                    age = 2020 - (2000 + int(first2Digits[1]))
                elif first2Digits[0] == '1':
                    age = 2020 - (2000 + int(first2Digits[:2]))
                else:
                    age = 2020 - (1900 + int(first2Digits[:2]))
            else:
                age = ""
            tempResult.append(str(age))
        ageList.append(','.join(tempResult))
    return ageList
dfNetworkScam['TargetAgeList'] = getTargetAge(dfNetworkScam['TargetESuid'].values)

# %%
dfNetworkScam['ESuid'] = dfNetworkScam['NeoIds'].map(lambda x:set([neoIdtoUidDict[i] for i in x if i in neoIdtoUidDict]))

# %%
dfNetworkScam['AllAgeList'] = getTargetAge(dfNetworkScam['ESuid'].values)

# %%
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-25_ScamSubgraphsDF.csv"
dfNetworkScam.to_csv(filename, index = False)

# %%
#import stopword
stopWordList = []
txtFile = "D:\\Users\\figohjs\\Documents\\NLP\\NER\\Data\\training\\stopwords.txt"
with open(txtFile, 'r') as myfile:
    for row in myfile.readlines():
        stopWordList.append(re.sub('\n','',row))

# %%
filename = "D:/Users/figohjs/Documents/Network/data/interim/2021-03-23_ScamSubgraphsDF.csv"
dfNetworkScam.to_csv(filename, index = False)
